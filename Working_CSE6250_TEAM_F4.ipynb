# %% [markdown]
# # GameNet Project reproduciblity code

# %% [markdown]
# # Introduction

# %% [markdown]
# Gamenet GAMENet: Graph Augmented MEmory networks for recommending medication combination by  tackles the limitation of instance-based recommendations with patient history to give better recommendations. It uses previous work that uses memory banks augmented by DDI graphs and dynamic memory based on patient history.
#
# It uses a novel deep learning approach by constructing 2 RNN hidden layers, one for diagnosis and one for procedure. It uses this constructed patient representation with a pre-generated memory bank from DDI graph and EHR graph. The papers claim that this approach outperforms all current baselines in effectiveness measures, and achieved 3.60% DDI rate reduction. (Shang, J. et al (2019))

# %% [markdown]
# # Scope of reproducibility

# %% [markdown]
# **Hypothesis 1**:
# The papers claim that this approach outperforms all current baselines in effectiveness measures, and achieved 3.60% DDI rate reduction. We will reproduce the results with our model to verify this measure is achieved.
#
# \
#
#
# **Hypothesis 2**:
# Author : Without DDI knowledge, GAMENet (w/o DDI) is also better than other methods which shows the overall framework does work
#
# We will evaluate if this holds true for the GAMENET model by comparing it with some pre established baselines created from other models.

# %% [markdown]
# # Data

# %% [markdown]
# ●	The data  raw data is the diagnoses, prescriptions, procedure data from MIMIC-3 . A freely-available database comprising deidentified health-related data associated with over forty thousand patients who stayed in critical care units of the Beth Israel Deaconess Medical Center between 2001 and 2012.( Johnson et al , 2016)
#
# ●	The data also includes drug-drug interaction (TWOSIDEs dataset) .Drug side effects and drug-drug interactions were mined from publicly available dat. (Offside , n. d.)

# %% [markdown]
# #Refining the dataset
# Note : the actual data processing generates pkl files and is being done at the bottom of the notebook . These files do not need to be regenerated and will be used in out model experiments below.
#
# ## Data Split
# Training data = 8/10
# Validation data = 2/10
#
# ##Create patient visit feature DB
# ●	we will remove duplicate entries from the 3 datasets\
# ●	the values will be sorted by subject_id\
# ●	there will be one row for each visit in the input dataset to the model\
# ●	we will group all the diagnoses, medication, and procedure codes into arrays for every visit. The medication array would be one of the expected outputs\
# ●	we will convert NDC to ATC\
# ●	we might do some limits on the number of procedures, medications, and diagnoses to keep in our testing due to processing constraints\
#
#
# # Creating feature vocabularies and patient record
# Each diagnosis code, Medication NDC code, and procedure code will be mapped to a unique feature value. These feature vocabularies  will be used in our modeling
# We will use the unique value to create another state of patient record which is numerical and therefore can be processed by the GAMENET model and any other model we may compare it against.
#
# Feature dictionary sample : \
# { \
#   "diag_1" : 1, \
#   "diag_2"  : 2, \
#   "diag_3" : 3 \
# }
#
# Patient Record format : [ [Diagnosis] , [Procedures] , [Medications] ]
#
# Patient record samples : \
# patient 1 : [ [1,2,3,7] , [6,7,5,4] , [3,4,6,8] ] \
# patient 2 : [ [3,7] , [7,5] , [4,6,8] ]
#
# # Creating adjacency matrix
# The adjacency matrix of DDI and NDC codes is needed to create the “memory banks” by running them through GCNs. These will be convoluted with input patient presentations to give an output. This is only needed to validate the results proposed in the model.
#
# Sample adjacency matrix showing DDI interaction \
# 0 - there is no drug drug interaction \
# 1 - there exists a Drug drug interaction \
#
#
# |       | med 1 | med 2 | med 3 |
# |-------|-------|-------|-------|
# | med 1 |       | 1     | 0     |
# | med 2 | 1     |       | 1     |
# | med 3 | 0     | 1     |       |

# %% [markdown]
# # Steps to run and setup
# STEP 1) Create a shortcut to the project in your home folder and run it from there
#
# STEP 2) **IMPORTANT** : Please replace the root folder of the project

# %%
# path_to_root_folder = '/content/drive/MyDrive/DL/BDHC/GAMENet/'
path_to_root_folder = "/content/drive/MyDrive/GAMENet"
path_to_code_folder=f"{path_to_root_folder}/code"

# %%
import os


def is_running_in_colab():
    return "google.colab" in str(get_ipython())

if is_running_in_colab():
    print("Running in Google Colab environment")
    is_colab = True
else:
    print("Not running in Google Colab environment")
    is_colab = False

if is_colab:
  from google.colab import drive
  drive.mount('/content/drive/')
  os.chdir(path_to_root_folder)
# Out:
# Running in Google Colab environment
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import sys
sys.path.append(path_to_code_folder)

# %%
# !pip install dill -q
# !pip install dnc -q

# %%
import torch

###############################
### DO NOT CHANGE THIS CELL ###
###############################

# Use cuda if present
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device available for running: ")
print(device)
# Out:
# Device available for running:
# cuda

# %% [markdown]
# #Model Recreation Code.

# %% [markdown]
# The cell below will define several helper function to help in training , validating , calculating scores and plotting

# %%
import torch.nn as nn
import torch.optim as optim
import dill
import numpy as np
import torch.nn.functional as F
import matplotlib.pyplot as plt
from util import *
from collections import defaultdict

#TODO : check if appropriate to copmare each position. The medication could be out of order. How to establish correct accuracy?
def accuracy_score(output, target):
    """
    Calculate accuracy score of the medication predictions
    """
    correct_predictions = np.sum(output == target)
    total_predictions = target.size
    return correct_predictions / total_predictions


def plot_learning_curves(train_losses, train_ddi_scores, valid_ddi_scores, train_accuracies=None, valid_losses=None, valid_accuracies=None):
  """
  Plot the learnin curve for
    -training accuracies
    -training ddi scores
    -training losses

    -valid accuracies
    -valid ddi scores
    -valid losses

  """
	# TODO: Make plots for loss curves and accuracy curves.
	# TODO: You do not have to return the plots.
	# TODO: You can save plots as files by codes here or an interactive way according to your preference.
  width=10
  epochs = np.arange(0,len(train_losses))

	# Plot loss curves
	# plt.figure(figsize=(10, 5))
  figure, axis  = plt.subplots(1, 2)
  if train_losses is not None :
      axis[0].plot(epochs, train_losses, label='Training Loss')

  if valid_losses is not None :
      axis[0].plot(epochs, valid_losses, label='Validation Loss')

  axis[0].set_xlabel('Epoch')
  axis[0].set_ylabel('Loss')
  axis[0].set_title('Loss Curves')
  axis[0].legend()



  #DDI SCORES
  if train_ddi_scores is not None :
      axis[1].plot(epochs, train_ddi_scores, label='Training DDI score')
      width = 15
  if valid_ddi_scores is not None :
      axis[1].plot(epochs, valid_ddi_scores, label='Validation DDI Score')
      width = 15

  axis[1].set_xlabel('Epoch')
  axis[1].set_ylabel('DDI_SCORE')
  axis[1].set_title('DDI_SCORE_GRAPH')
  axis[1].legend()


  figure.set_size_inches(w=width, h=5)
  plt.savefig('trainingplots.png')
  plt.show()

def plot_learning_curves_2(curves):
  """
  Plot the learnin curve for
    -training accuracies
    -training ddi scores
    -training losses

    -valid accuracies
    -valid ddi scores
    -valid losses

  """
	# TODO: Make plots for loss curves and accuracy curves.
	# TODO: You do not have to return the plots.
	# TODO: You can save plots as files by codes here or an interactive way according to your preference.
  width = len(curves) * 5
  figure, axis  = plt.subplots(1, len(curves))
  epochs = np.arange(0,len(curves[0][0]))


  for index,curve in enumerate(curves):

    c = curve[0]
    label = curve[1]
    x_label = curve[2]
    y_label = curve[3]
    title = curve[4]
    print(label,title)
    print(len(c))


    axis[index].plot(epochs, c, label=label)
    axis[index].set_xlabel(x_label)
    axis[index].set_ylabel(y_label)
    axis[index].set_title(title)
    axis[index].legend()

  figure.set_size_inches(w=width, h=5)
  plt.savefig('outputs.png')
  plt.show()

def plot_learning_curves_3(curves):
  """
  Plot the learnin curve for
    -training accuracies
    -training ddi scores
    -training losses

    -valid accuracies
    -valid ddi scores
    -valid losses

  """
	# TODO: Make plots for loss curves and accuracy curves.
	# TODO: You do not have to return the plots.
	# TODO: You can save plots as files by codes here or an interactive way according to your preference.
  figure = plt.figure(1)
  num_curves = len(curves)

  width = len(curves) * 5
  epochs = np.arange(0,len(curves[0][0]))


  for index,curve in enumerate(curves):

    c = curve[0]
    label = curve[1]
    x_label = curve[2]
    y_label = curve[3]
    title = curve[4]
    # print(label,title)
    # print(len(c))
    plt.figure(index + 1)

    plt.plot(epochs, c, label=label)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    plt.legend()

  plt.savefig('outputs.png')
  plt.show()

def ddi_rate_score(record, path='data/ddi_A_final.pkl'):
    '''
    this calculates the ddi and we borrowed this from the original paper
    '''
    ddi_A = dill.load(open(path, 'rb'))
    all_cnt = 0
    dd_cnt = 0
    for patient in record:
        for adm in patient:
            med_code_set = adm
            for i, med_i in enumerate(med_code_set):
                for j, med_j in enumerate(med_code_set):
                    if j <= i:
                        continue
                    all_cnt += 1
                    if ddi_A[med_i, med_j] == 1 or ddi_A[med_j, med_i] == 1:
                        dd_cnt += 1
    if all_cnt == 0:
        return 0
    return dd_cnt / all_cnt
    # return all_cnt/dd_cnt

def eval(model, data, voc_size, epoch, test_code_logic=False):
    # evaluate
    print('')
    model.eval()
    smm_record = []
    ja, prauc, avg_p, avg_r, avg_f1 = [[] for _ in range(5)]
    case_study = defaultdict(dict)
    med_cnt = 0
    visit_cnt = 0
    for patient, visits in enumerate(data):
        y_gt = []
        y_pred = []
        y_pred_prob = []
        y_pred_label = []
          # for adm_idx, adm in enumerate(input):
        for idx, visit in enumerate(visits):

            target_output1 = model(visits[:idx+1])

            y_gt_tmp = np.zeros(voc_size[2])
            y_gt_tmp[visit[2]] = 1
            y_gt.append(y_gt_tmp)

            target_output1 = F.sigmoid(target_output1).detach().cpu().numpy()[0]
            y_pred_prob.append(target_output1)
            y_pred_tmp = target_output1.copy()
            y_pred_tmp[y_pred_tmp>=0.5] = 1
            y_pred_tmp[y_pred_tmp<0.5] = 0
            y_pred.append(y_pred_tmp)
            y_pred_label_tmp = np.where(y_pred_tmp == 1)[0]
            y_pred_label.append(sorted(y_pred_label_tmp))
            visit_cnt += 1
            med_cnt += len(y_pred_label_tmp)

        smm_record.append(y_pred_label)
        adm_ja, adm_prauc, adm_avg_p, adm_avg_r, adm_avg_f1 = multi_label_metric(np.array(y_gt), np.array(y_pred), np.array(y_pred_prob))
        case_study[adm_ja] = {'ja': adm_ja, 'patient': visits, 'y_label': y_pred_label}

        ja.append(adm_ja)
        prauc.append(adm_prauc)
        avg_p.append(adm_avg_p)
        avg_r.append(adm_avg_r)
        avg_f1.append(adm_avg_f1)
        print('\rEval--Epoch: %d, Step: %d/%d' % (epoch, patient, len(data)))

        if test_code_logic:
          break

    # ddi rate
    ddi_rate = ddi_rate_score(smm_record)

    print('\tDDI Rate: %.4f, Jaccard: %.4f,  PRAUC: %.4f, AVG_PRC: %.4f, AVG_RECALL: %.4f, AVG_F1: %.4f\n' % (
        ddi_rate, np.mean(ja), np.mean(prauc), np.mean(avg_p), np.mean(avg_r), np.mean(avg_f1)
    ))
    # dill.dump(obj=smm_record, file=open('../data/gamenet_records.pkl', 'wb'))
    # dill.dump(case_study, open(os.path.join('saved', model_name, 'case_study.pkl'), 'wb'))

    # print('avg med', med_cnt / visit_cnt)

    return ddi_rate, np.mean(ja), np.mean(prauc), np.mean(avg_p), np.mean(avg_r), np.mean(avg_f1)


def validate(data, model, voc_size, train_code=False):

    valid_losses = []  #lower the better
    ddi_scores = [] #lower the better

    model.eval()
    with torch.no_grad():
        for patient, visits in enumerate(data):
            for idx, medical_features in enumerate(visits):
                seq_input = visits[:idx+1]  #get all the visits until the current visit

                #target is the medication for the patient
                target = np.zeros((1, voc_size[2]))
                target[:, medical_features[2]] = 1


                for idx, item in enumerate(medical_features[2]):
                      loss3_target[0][idx] = item

                # print(target)
                target_output1 = F.sigmoid(target_output1).detach().cpu().numpy()[0]
                y_pred_tmp = target_output1.copy()
                y_pred_tmp[y_pred_tmp>=0.5] = 1
                y_pred_tmp[y_pred_tmp<0.5] = 0
                y_pred_label_tmp = np.where(y_pred_tmp == 1)[0]
                visit_cnt += 1
                med_cnt += len(y_pred_label_tmp)


                # normalising output
                output = F.sigmoid(output).detach().cpu().numpy()[0]
                output[output >= 0.5] = 1
                output[output < 0.5] = 0
                y_label = np.where(output == 1)[0]
                ddi_score = ddi_rate_score([[y_label]])

                loss_i = float((loss.detach().cpu().numpy()))
                ddi_score_i = float(current_ddi_rate)

                # print("output is ",output)
                valid_accuracies = accuracy_score(output, target)
                valid_losses.append(loss_i)
                ddi_scores.append(ddi_score_i)



    return valid_losses, valid_accuracies, ddi_scores

def train(model,data,optimizer,voc_size,test_code_logic=False):
    model.train()
    train_losses = []  #lower the better
    ddi_scores = [] #lower the better
    TARGET_DDI = 0.05
    Neg_Loss = True
    T = 0.5

    for patient, visits in enumerate(data):
        for idx, medical_features in enumerate(visits):
            seq_input = visits[:idx+1]  #get all the visits until the current visit

            #target is the medication for the patient
            target = np.zeros((1, voc_size[2]))
            target[:, medical_features[2]] = 1

            loss3_target = np.full((1, voc_size[2]), -1)
            for idx, item in enumerate(medical_features[2]):
                loss3_target[0][idx] = item


            output, batch_neg_loss = model(seq_input)
            loss1 = F.binary_cross_entropy_with_logits(output, torch.FloatTensor(target).to(device))
            loss3 = F.multilabel_margin_loss(F.sigmoid(output), torch.LongTensor(loss3_target).to(device))
            if Neg_Loss:
                output = F.sigmoid(output).detach().cpu().numpy()[0]
                output[output >= 0.5] = 1
                output[output < 0.5] = 0
                y_label = np.where(output == 1)[0]
                current_ddi_rate = ddi_rate_score([[y_label]])
                if current_ddi_rate <= TARGET_DDI:
                    loss = 0.9 * loss1 + 0.01 * loss3
                    # prediction_loss_cnt += 1
                else:
                    rnd = np.exp((TARGET_DDI - current_ddi_rate)/T)
                    if np.random.rand(1) < rnd:
                        loss = batch_neg_loss
                        # neg_loss_cnt += 1
                    else:
                        loss = 0.9 * loss1 + 0.01 * loss3
                        # prediction_loss_cnt += 1
            else:
                loss = 0.9 * loss1 + 0.01 * loss3

            # # print(target)
            # output, batch_neg_loss = model(seq_input)
            # loss = F.binary_cross_entropy_with_logits(output, torch.FloatTensor(target).to(device))

            # # normalising output
            # output = F.sigmoid(output).detach().cpu().numpy()[0]
            # output[output >= 0.5] = 1
            # output[output < 0.5] = 0
            # y_label = np.where(output == 1)[0]
            # ddi_score = ddi_rate_score([[y_label]])





            loss_i = float((loss.detach().cpu().numpy()))
            ddi_score_i = float(current_ddi_rate)

            train_losses.append(loss_i)
            ddi_scores.append(ddi_score_i)
            optimizer.zero_grad()
            train_accuracies = accuracy_score(output, target)
            loss.backward(retain_graph=True)
            optimizer.step()

        if test_code_logic:
          break

    return train_losses, train_accuracies, ddi_scores

def validate_cuda(data, model, voc_size, device = device):
    valid_losses = []  # Lower the better
    ddi_scores = []  # Lower the better
    model.eval()

    with torch.no_grad():
        for patient in data:
            for visits in patient:
                seq_input = torch.tensor(visits[:], dtype=torch.float).to(device)
                target = torch.zeros((1, voc_size[2]), dtype=torch.float).to(device)
                target[:, visits[2]] = 1  # Assuming this is the correct way to set the target

                output = model(seq_input)
                loss = nn.functional.binary_cross_entropy_with_logits(output, target)

                output = torch.sigmoid(output).cpu().numpy()[0]
                output[output >= 0.5] = 1
                output[output < 0.5] = 0
                y_label = np.where(output == 1)[0]
                ddi_score = ddi_rate_score([[y_label]])

                valid_losses.append(loss.item())
                ddi_scores.append(float(ddi_score))

    return valid_losses, ddi_scores

def train_cuda(model, data, optimizer, voc_size, device = device):
    model.train()
    train_losses = []  # Lower the better
    ddi_scores = []  # Lower the better

    for patient in data:
        for visits in patient:
            seq_input = torch.tensor(visits[:], dtype=torch.float).to(device)
            target = torch.zeros((1, voc_size[2]), dtype=torch.float).to(device)
            target[:, visits[2]] = 1  # Assuming this is the correct way to set the target

            optimizer.zero_grad()
            output = model(seq_input)
            loss = nn.functional.binary_cross_entropy_with_logits(output, target)

            loss.backward()
            optimizer.step()

            output = torch.sigmoid(output).detach().cpu().numpy()[0]
            output[output >= 0.5] = 1
            output[output < 0.5] = 0
            y_label = np.where(output == 1)[0]
            ddi_score = ddi_rate_score([[y_label]])

            train_accuracies = accuracy_score(output, target)

            train_losses.append(loss.item())
            ddi_scores.append(float(ddi_score))

    return train_losses, train_accuracies, ddi_scores

# %% [markdown]
# ## The cells below is doing a short description of our model and defining it in code.

# %% [markdown]
# # Modelling Write up

# %% [markdown]
# Our final model will follow the architecture outlined in the paper.
#
# ### Data Input
# There is 2 visit sequences that are ran through the model the include history of procedures and diagnoses by another patient .  They are of size , (visit_dim, procedure_count) and (visit_dim,diagnoses_count). Visit size will include the 0th visit to the current visit. We will also send the in the medication in the same format as it will be used for key value store.
# For initial experiment we are using\
# Diagnosis   count 	1958
# Medications prescribed count	145
# Procedure count	1426\
#
# ###Embedding Network
# Each vector(medication, diagnosis, procedure) will be reduced using an embedding which will output a size emb_dim which is set at 64 for now.
# Dual RNN\
# GRU will be used for this step . We will have one GRU for diagnoses and one for procedures. The input dimension would be 64 as that is the output of embedding network. The output dimension will be doubled.
# ###Patient Representation and query
# We combine the GRU results by doing a concatenation to create a patient representation of procedure and diagnoses.
# We run this through a linear layer with RelU to get a queries for the entire sequence.
# The current query is the last element .
# ### Memory Bank
# This is created using the adjacency matrix created in the data pre-processing sections. We created 2 Graph convoluted networks, one for EHR adjacency matrix and one for DDI. We use the implementation provided in the paper to create these GCNs. It doesn’t have input, just weights associated with the adjacency matrix that are adjusted during training
# ###Key Value store
# The keys are all the queries for the past visits. This is taken from the GRU results.
# The values are the medication for the past visits.
# ### Ob and od
# Ob = memory_bank_contribution = softmax(query  . memory_bank_transpose). Memory_bank \
# Od = key-store contribution = memory_bank . (key_value_store_values). Softmax(key store keys . query)
#
# ### Sigmoid Output
# We apply a sigmoid out to each of the outputs to scale them between 0 and 1. Anything above 0.5 is assumed 1 and anything below 0.5 is assumed 0.
# ###Combined Loss
# We calculate the losses from the model after evaluatin each visit in each patient . There are 2 different losses that we take a look at: \
# 1) **Binary cross entropy loss** \
# We calculate the loss between the target output and the expected medication vector both in a binary form with array index represeting medication feature.
#
# 2) **Muti label margin loss**
# This is used to maximise probablities . We contruct a target loss consisting of -1 and the medical feature value . ie [3,4,5,-1,-1,-1]. We use this to calculate loss on sigmoid(model_ouput)
#
# The loss is combined to a single loss:
# loss = 0.9 * Loss_BCE + 0.01 * Loss_MML
#
#
#
# ###DDI Score
# The features of medications sigmoid output will be fed into the ddi_score function to calculate drug-drug interaction scores. We will aim to minimize this function along with the loss of the predicted medications.

# %%
from models import GCN

class GAMENet(nn.Module):
    def __init__(self, vocab_size, ehr_adj, ddi_adj, emb_dim=64, device=torch.device('cpu:0'), ddi_in_memory=True):
        super(GAMENet, self).__init__()
        K = len(vocab_size)
        self.K = K
        self.vocab_size = vocab_size
        self.device = device
        self.tensor_ddi_adj = torch.FloatTensor(ddi_adj).to(device)
        self.ddi_in_memory = ddi_in_memory
        self.embeddings = nn.ModuleList(
            [nn.Embedding(vocab_size[i], emb_dim) for i in range(K-1)])
        self.dropout = nn.Dropout(p=0.4)

        self.encoders = nn.ModuleList([nn.GRU(emb_dim, emb_dim*2, batch_first=True) for _ in range(K-1)])

        self.query = nn.Sequential(
            nn.ReLU(),
            nn.Linear(emb_dim * 4, emb_dim),
        )

        self.ehr_gcn = GCN(voc_size=vocab_size[2], emb_dim=emb_dim, adj=ehr_adj, device=device)
        self.ddi_gcn = GCN(voc_size=vocab_size[2], emb_dim=emb_dim, adj=ddi_adj, device=device)
        self.inter = nn.Parameter(torch.FloatTensor(1))

        self.output = nn.Sequential(
            nn.ReLU(),
            nn.Linear(emb_dim * 3, emb_dim * 2),
            nn.ReLU(),
            nn.Linear(emb_dim * 2, vocab_size[2])
        )

        self.init_weights()

    def forward(self, input):
        # input (adm, 3, codes)

        # generate medical embeddings and queries
        i1_seq = []
        i2_seq = []
        def mean_embedding(embedding):
            return embedding.mean(dim=1).unsqueeze(dim=0)  # (1,1,dim)
        for adm in input:
            i1 = mean_embedding(self.dropout(self.embeddings[0](torch.LongTensor(adm[0]).unsqueeze(dim=0).to(self.device)))) # (1,1,dim)
            i2 = mean_embedding(self.dropout(self.embeddings[1](torch.LongTensor(adm[1]).unsqueeze(dim=0).to(self.device))))
            i1_seq.append(i1)
            i2_seq.append(i2)
        i1_seq = torch.cat(i1_seq, dim=1) #(1,seq,dim)
        i2_seq = torch.cat(i2_seq, dim=1) #(1,seq,dim)

        o1, h1 = self.encoders[0](
            i1_seq
        ) # o1:(1, seq, dim*2) hi:(1,1,dim*2)
        o2, h2 = self.encoders[1](
            i2_seq
        )
        patient_representations = torch.cat([o1, o2], dim=-1).squeeze(dim=0) # (seq, dim*4)
        queries = self.query(patient_representations) # (seq, dim)

        # graph memory module
        '''I:generate current input'''
        query = queries[-1:] # (1,dim)

        '''G:generate graph memory bank and insert history information'''
        if self.ddi_in_memory:
            drug_memory = self.ehr_gcn() - self.ddi_gcn() * self.inter  # (size, dim)
        else:
            drug_memory = self.ehr_gcn()

        if len(input) > 1:
            history_keys = queries[:(queries.size(0)-1)] # (seq-1, dim)

            history_values = np.zeros((len(input)-1, self.vocab_size[2]))
            for idx, adm in enumerate(input):
                if idx == len(input)-1:
                    break
                history_values[idx, adm[2]] = 1
            history_values = torch.FloatTensor(history_values).to(self.device) # (seq-1, size)

        '''O:read from global memory bank and dynamic memory bank'''
        key_weights1 = F.softmax(torch.mm(query, drug_memory.t()), dim=-1)  # (1, size)
        fact1 = torch.mm(key_weights1, drug_memory)  # (1, dim)

        if len(input) > 1:
            visit_weight = F.softmax(torch.mm(query, history_keys.t())) # (1, seq-1)
            weighted_values = visit_weight.mm(history_values) # (1, size)
            fact2 = torch.mm(weighted_values, drug_memory) # (1, dim)
        else:
            fact2 = fact1
        '''R:convert O and predict'''
        output = self.output(torch.cat([query, fact1, fact2], dim=-1)) # (1, dim)

        if self.training:
            neg_pred_prob = F.sigmoid(output)
            neg_pred_prob = neg_pred_prob.t() * neg_pred_prob  # (voc_size, voc_size)
            batch_neg = neg_pred_prob.mul(self.tensor_ddi_adj).mean()

            return output, batch_neg
        else:
            return output

    def init_weights(self):
        """Initialize weights."""
        initrange = 0.1
        for item in self.embeddings:
            item.weight.data.uniform_(-initrange, initrange)

        self.inter.data.uniform_(-initrange, initrange)

# %% [markdown]
# ##The cell below is running the training and validation to generate the plots

# %%
# Some parameters
NUM_EPOCHS = 1
USE_CUDA = True  # Set 'True' if you want to use GPU
NUM_WORKERS = 4  # Number of threads used by DataLoader. You can adjust this according to your machine spec.

device = torch.device("cuda" if USE_CUDA and torch.cuda.is_available() else "cpu")
torch.manual_seed(1)

# LOADING DATA
data_path = 'data/records_final.pkl'
voc_path = 'data/voc_final.pkl'
voc_path = 'voc_final.pkl'

ehr_adj_path = 'data/ehr_adj_final.pkl'
ddi_adj_path = 'data/ddi_A_final.pkl'
# device = torch.device('cpu')

ehr_adj = dill.load(open(ehr_adj_path, 'rb'))
ddi_adj = dill.load(open(ddi_adj_path, 'rb'))
data = dill.load(open(data_path, 'rb'))
voc = dill.load(open(voc_path, 'rb'))
diag_voc, pro_voc, med_voc = voc['diag_voc'], voc['pro_voc'], voc['med_voc']
voc_size = (len(diag_voc.idx2word), len(pro_voc.idx2word), len(med_voc.idx2word))

# MODEL
print(f"running model in {device}")
model = GAMENet(voc_size, ehr_adj, ddi_adj, emb_dim=64, device=device, ddi_in_memory=True)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters())
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print (f"Using device {device}")
model.to(device)
criterion.to(device)


# DATA SPLIT
split_point = int(len(data) * 8/10)
data_train = data[:split_point]
# data_valid

# TRAINING
#medical_features[0] = diagnoses
#medical_features[1] = procedures
#medical_features[2] = medication

# INIT TRACKERS
average_train_losses = []  #lower the better
average_train_accuracies = []
average_train_ddi_scores = [] #lower the better


average_valid_ddi_scores = []
average_valid_ja = []
average_valid_prauc = []
average_valid_p = []
average_valid_r = []
average_valid_f1 = []

TEST_CODE_LOGIC = False

for epoch in range(NUM_EPOCHS):
    print(f"Running epoch {epoch}")
    train_losses, train_accuracies, train_ddi_scores = train(model=model, data=data_train,optimizer=optimizer,voc_size=voc_size,test_code_logic=TEST_CODE_LOGIC)
    ddi_rate, ja, prauc, avg_p, avg_r, avg_f1 = eval(model=model,data=data_train,voc_size=voc_size,epoch=epoch,test_code_logic=TEST_CODE_LOGIC)

    print(np.average(np.array(train_losses)),np.average(np.array(train_accuracies)),np.average(np.array(train_ddi_scores)),ddi_rate, ja, prauc, avg_p, avg_r, avg_f1)

    average_train_losses.append(np.average(np.array(train_losses)))
    average_train_accuracies.append(np.average(np.array(train_accuracies)))
    average_train_ddi_scores.append(np.average(np.array(train_ddi_scores)))

    average_valid_ddi_scores.append(ddi_rate)
    average_valid_ja.append(ja)
    average_valid_prauc.append(prauc)
    average_valid_p.append(avg_p)
    average_valid_r.append(avg_r)
    average_valid_f1.append(avg_f1)

# Strucutre of curves array tuples
# c = curves[0]
# label = curves[1]
# x_label = curves[2]
# y_label = curves[3]
# title = curves[4]


curves = [
    (average_train_losses,'train_losses','epoch','loss','train loss'),
    (average_train_accuracies,'train_accuracies','epoch','accuracy','train accuracy'),
    (average_train_ddi_scores,'train_ddi_score','epoch','ddi_score','train ddi score'),
    (average_valid_ddi_scores,'train_ddi_score','epoch','ddi_score','valid ddi score'),
    (average_valid_ja,'valid_ja','epoch','jaccard score','valid jaccard score'),
    (average_valid_prauc,'valid_prauc','epoch','prauc','valid prauc'),
    (average_valid_p,'valid p','epoch','p','valid p'),
    (average_valid_r,'valid r','epoch','r','valid r'),
    (average_valid_f1,'valid f1','epoch','f1','valid f1')
]

plot_learning_curves_3(curves)
# Out:
# Streaming output truncated to the last 5000 lines.
# Eval--Epoch: 9, Step: 83/5080
# Eval--Epoch: 9, Step: 84/5080
# Eval--Epoch: 9, Step: 85/5080
# Eval--Epoch: 9, Step: 86/5080
# Eval--Epoch: 9, Step: 87/5080
# Eval--Epoch: 9, Step: 88/5080
# Eval--Epoch: 9, Step: 89/5080
# Eval--Epoch: 9, Step: 90/5080
# Eval--Epoch: 9, Step: 91/5080
# Eval--Epoch: 9, Step: 92/5080
# Eval--Epoch: 9, Step: 93/5080
# Eval--Epoch: 9, Step: 94/5080
# Eval--Epoch: 9, Step: 95/5080
# Eval--Epoch: 9, Step: 96/5080
# Eval--Epoch: 9, Step: 97/5080
# Eval--Epoch: 9, Step: 98/5080
# Eval--Epoch: 9, Step: 99/5080
# Eval--Epoch: 9, Step: 100/5080
# Eval--Epoch: 9, Step: 101/5080
# Eval--Epoch: 9, Step: 102/5080
# Eval--Epoch: 9, Step: 103/5080
# Eval--Epoch: 9, Step: 104/5080
# Eval--Epoch: 9, Step: 105/5080
# Eval--Epoch: 9, Step: 106/5080
# Eval--Epoch: 9, Step: 107/5080
# Eval--Epoch: 9, Step: 108/5080
# Eval--Epoch: 9, Step: 109/5080
# Eval--Epoch: 9, Step: 110/5080
# Eval--Epoch: 9, Step: 111/5080
# Eval--Epoch: 9, Step: 112/5080
# Eval--Epoch: 9, Step: 113/5080
# Eval--Epoch: 9, Step: 114/5080
# Eval--Epoch: 9, Step: 115/5080
# Eval--Epoch: 9, Step: 116/5080
# Eval--Epoch: 9, Step: 117/5080
# Eval--Epoch: 9, Step: 118/5080
# Eval--Epoch: 9, Step: 119/5080
# Eval--Epoch: 9, Step: 120/5080
# Eval--Epoch: 9, Step: 121/5080
# Eval--Epoch: 9, Step: 122/5080
# Eval--Epoch: 9, Step: 123/5080
# Eval--Epoch: 9, Step: 124/5080
# Eval--Epoch: 9, Step: 125/5080
# Eval--Epoch: 9, Step: 126/5080
# Eval--Epoch: 9, Step: 127/5080
# Eval--Epoch: 9, Step: 128/5080
# Eval--Epoch: 9, Step: 129/5080
# Eval--Epoch: 9, Step: 130/5080
# Eval--Epoch: 9, Step: 131/5080
# Eval--Epoch: 9, Step: 132/5080
# Eval--Epoch: 9, Step: 133/5080
# Eval--Epoch: 9, Step: 134/5080
# Eval--Epoch: 9, Step: 135/5080
# Eval--Epoch: 9, Step: 136/5080
# Eval--Epoch: 9, Step: 137/5080
# Eval--Epoch: 9, Step: 138/5080
# Eval--Epoch: 9, Step: 139/5080
# Eval--Epoch: 9, Step: 140/5080
# Eval--Epoch: 9, Step: 141/5080
# Eval--Epoch: 9, Step: 142/5080
# Eval--Epoch: 9, Step: 143/5080
# Eval--Epoch: 9, Step: 144/5080
# Eval--Epoch: 9, Step: 145/5080
# Eval--Epoch: 9, Step: 146/5080
# Eval--Epoch: 9, Step: 147/5080
# Eval--Epoch: 9, Step: 148/5080
# Eval--Epoch: 9, Step: 149/5080
# Eval--Epoch: 9, Step: 150/5080
# Eval--Epoch: 9, Step: 151/5080
# Eval--Epoch: 9, Step: 152/5080
# Eval--Epoch: 9, Step: 153/5080
# Eval--Epoch: 9, Step: 154/5080
# Eval--Epoch: 9, Step: 155/5080
# Eval--Epoch: 9, Step: 156/5080
# Eval--Epoch: 9, Step: 157/5080
# Eval--Epoch: 9, Step: 158/5080
# Eval--Epoch: 9, Step: 159/5080
# Eval--Epoch: 9, Step: 160/5080
# Eval--Epoch: 9, Step: 161/5080
# Eval--Epoch: 9, Step: 162/5080
# Eval--Epoch: 9, Step: 163/5080
# Eval--Epoch: 9, Step: 164/5080
# Eval--Epoch: 9, Step: 165/5080
# Eval--Epoch: 9, Step: 166/5080
# Eval--Epoch: 9, Step: 167/5080
# Eval--Epoch: 9, Step: 168/5080
# Eval--Epoch: 9, Step: 169/5080
# Eval--Epoch: 9, Step: 170/5080
# Eval--Epoch: 9, Step: 171/5080
# Eval--Epoch: 9, Step: 172/5080
# Eval--Epoch: 9, Step: 173/5080
# Eval--Epoch: 9, Step: 174/5080
# Eval--Epoch: 9, Step: 175/5080
# Eval--Epoch: 9, Step: 176/5080
# Eval--Epoch: 9, Step: 177/5080
# Eval--Epoch: 9, Step: 178/5080
# Eval--Epoch: 9, Step: 179/5080
# Eval--Epoch: 9, Step: 180/5080
# Eval--Epoch: 9, Step: 181/5080
# Eval--Epoch: 9, Step: 182/5080
# Eval--Epoch: 9, Step: 183/5080
# Eval--Epoch: 9, Step: 184/5080
# Eval--Epoch: 9, Step: 185/5080
# Eval--Epoch: 9, Step: 186/5080
# Eval--Epoch: 9, Step: 187/5080
# Eval--Epoch: 9, Step: 188/5080
# Eval--Epoch: 9, Step: 189/5080
# Eval--Epoch: 9, Step: 190/5080
# Eval--Epoch: 9, Step: 191/5080
# Eval--Epoch: 9, Step: 192/5080
# Eval--Epoch: 9, Step: 193/5080
# Eval--Epoch: 9, Step: 194/5080
# Eval--Epoch: 9, Step: 195/5080
# Eval--Epoch: 9, Step: 196/5080
# Eval--Epoch: 9, Step: 197/5080
# Eval--Epoch: 9, Step: 198/5080
# Eval--Epoch: 9, Step: 199/5080
# Eval--Epoch: 9, Step: 200/5080
# Eval--Epoch: 9, Step: 201/5080
# Eval--Epoch: 9, Step: 202/5080
# Eval--Epoch: 9, Step: 203/5080
# Eval--Epoch: 9, Step: 204/5080
# Eval--Epoch: 9, Step: 205/5080
# Eval--Epoch: 9, Step: 206/5080
# Eval--Epoch: 9, Step: 207/5080
# Eval--Epoch: 9, Step: 208/5080
# Eval--Epoch: 9, Step: 209/5080
# Eval--Epoch: 9, Step: 210/5080
# Eval--Epoch: 9, Step: 211/5080
# Eval--Epoch: 9, Step: 212/5080
# Eval--Epoch: 9, Step: 213/5080
# Eval--Epoch: 9, Step: 214/5080
# Eval--Epoch: 9, Step: 215/5080
# Eval--Epoch: 9, Step: 216/5080
# Eval--Epoch: 9, Step: 217/5080
# Eval--Epoch: 9, Step: 218/5080
# Eval--Epoch: 9, Step: 219/5080
# Eval--Epoch: 9, Step: 220/5080
# Eval--Epoch: 9, Step: 221/5080
# Eval--Epoch: 9, Step: 222/5080
# Eval--Epoch: 9, Step: 223/5080
# Eval--Epoch: 9, Step: 224/5080
# Eval--Epoch: 9, Step: 225/5080
# Eval--Epoch: 9, Step: 226/5080
# Eval--Epoch: 9, Step: 227/5080
# Eval--Epoch: 9, Step: 228/5080
# Eval--Epoch: 9, Step: 229/5080
# Eval--Epoch: 9, Step: 230/5080
# Eval--Epoch: 9, Step: 231/5080
# Eval--Epoch: 9, Step: 232/5080
# Eval--Epoch: 9, Step: 233/5080
# Eval--Epoch: 9, Step: 234/5080
# Eval--Epoch: 9, Step: 235/5080
# Eval--Epoch: 9, Step: 236/5080
# Eval--Epoch: 9, Step: 237/5080
# Eval--Epoch: 9, Step: 238/5080
# Eval--Epoch: 9, Step: 239/5080
# Eval--Epoch: 9, Step: 240/5080
# Eval--Epoch: 9, Step: 241/5080
# Eval--Epoch: 9, Step: 242/5080
# Eval--Epoch: 9, Step: 243/5080
# Eval--Epoch: 9, Step: 244/5080
# Eval--Epoch: 9, Step: 245/5080
# Eval--Epoch: 9, Step: 246/5080
# Eval--Epoch: 9, Step: 247/5080
# Eval--Epoch: 9, Step: 248/5080
# Eval--Epoch: 9, Step: 249/5080
# Eval--Epoch: 9, Step: 250/5080
# Eval--Epoch: 9, Step: 251/5080
# Eval--Epoch: 9, Step: 252/5080
# Eval--Epoch: 9, Step: 253/5080
# Eval--Epoch: 9, Step: 254/5080
# Eval--Epoch: 9, Step: 255/5080
# Eval--Epoch: 9, Step: 256/5080
# Eval--Epoch: 9, Step: 257/5080
# Eval--Epoch: 9, Step: 258/5080
# Eval--Epoch: 9, Step: 259/5080
# Eval--Epoch: 9, Step: 260/5080
# Eval--Epoch: 9, Step: 261/5080
# Eval--Epoch: 9, Step: 262/5080
# Eval--Epoch: 9, Step: 263/5080
# Eval--Epoch: 9, Step: 264/5080
# Eval--Epoch: 9, Step: 265/5080
# Eval--Epoch: 9, Step: 266/5080
# Eval--Epoch: 9, Step: 267/5080
# Eval--Epoch: 9, Step: 268/5080
# Eval--Epoch: 9, Step: 269/5080
# Eval--Epoch: 9, Step: 270/5080
# Eval--Epoch: 9, Step: 271/5080
# Eval--Epoch: 9, Step: 272/5080
# Eval--Epoch: 9, Step: 273/5080
# Eval--Epoch: 9, Step: 274/5080
# Eval--Epoch: 9, Step: 275/5080
# Eval--Epoch: 9, Step: 276/5080
# Eval--Epoch: 9, Step: 277/5080
# Eval--Epoch: 9, Step: 278/5080
# Eval--Epoch: 9, Step: 279/5080
# Eval--Epoch: 9, Step: 280/5080
# Eval--Epoch: 9, Step: 281/5080
# Eval--Epoch: 9, Step: 282/5080
# Eval--Epoch: 9, Step: 283/5080
# Eval--Epoch: 9, Step: 284/5080
# Eval--Epoch: 9, Step: 285/5080
# Eval--Epoch: 9, Step: 286/5080
# Eval--Epoch: 9, Step: 287/5080
# Eval--Epoch: 9, Step: 288/5080
# Eval--Epoch: 9, Step: 289/5080
# Eval--Epoch: 9, Step: 290/5080
# Eval--Epoch: 9, Step: 291/5080
# Eval--Epoch: 9, Step: 292/5080
# Eval--Epoch: 9, Step: 293/5080
# Eval--Epoch: 9, Step: 294/5080
# Eval--Epoch: 9, Step: 295/5080
# Eval--Epoch: 9, Step: 296/5080
# Eval--Epoch: 9, Step: 297/5080
# Eval--Epoch: 9, Step: 298/5080
# Eval--Epoch: 9, Step: 299/5080
# Eval--Epoch: 9, Step: 300/5080
# Eval--Epoch: 9, Step: 301/5080
# Eval--Epoch: 9, Step: 302/5080
# Eval--Epoch: 9, Step: 303/5080
# Eval--Epoch: 9, Step: 304/5080
# Eval--Epoch: 9, Step: 305/5080
# Eval--Epoch: 9, Step: 306/5080
# Eval--Epoch: 9, Step: 307/5080
# Eval--Epoch: 9, Step: 308/5080
# Eval--Epoch: 9, Step: 309/5080
# Eval--Epoch: 9, Step: 310/5080
# Eval--Epoch: 9, Step: 311/5080
# Eval--Epoch: 9, Step: 312/5080
# Eval--Epoch: 9, Step: 313/5080
# Eval--Epoch: 9, Step: 314/5080
# Eval--Epoch: 9, Step: 315/5080
# Eval--Epoch: 9, Step: 316/5080
# Eval--Epoch: 9, Step: 317/5080
# Eval--Epoch: 9, Step: 318/5080
# Eval--Epoch: 9, Step: 319/5080
# Eval--Epoch: 9, Step: 320/5080
# Eval--Epoch: 9, Step: 321/5080
# Eval--Epoch: 9, Step: 322/5080
# Eval--Epoch: 9, Step: 323/5080
# Eval--Epoch: 9, Step: 324/5080
# Eval--Epoch: 9, Step: 325/5080
# Eval--Epoch: 9, Step: 326/5080
# Eval--Epoch: 9, Step: 327/5080
# Eval--Epoch: 9, Step: 328/5080
# Eval--Epoch: 9, Step: 329/5080
# Eval--Epoch: 9, Step: 330/5080
# Eval--Epoch: 9, Step: 331/5080
# Eval--Epoch: 9, Step: 332/5080
# Eval--Epoch: 9, Step: 333/5080
# Eval--Epoch: 9, Step: 334/5080
# Eval--Epoch: 9, Step: 335/5080
# Eval--Epoch: 9, Step: 336/5080
# Eval--Epoch: 9, Step: 337/5080
# Eval--Epoch: 9, Step: 338/5080
# Eval--Epoch: 9, Step: 339/5080
# Eval--Epoch: 9, Step: 340/5080
# Eval--Epoch: 9, Step: 341/5080
# Eval--Epoch: 9, Step: 342/5080
# Eval--Epoch: 9, Step: 343/5080
# Eval--Epoch: 9, Step: 344/5080
# Eval--Epoch: 9, Step: 345/5080
# Eval--Epoch: 9, Step: 346/5080
# Eval--Epoch: 9, Step: 347/5080
# Eval--Epoch: 9, Step: 348/5080
# Eval--Epoch: 9, Step: 349/5080
# Eval--Epoch: 9, Step: 350/5080
# Eval--Epoch: 9, Step: 351/5080
# Eval--Epoch: 9, Step: 352/5080
# Eval--Epoch: 9, Step: 353/5080
# Eval--Epoch: 9, Step: 354/5080
# Eval--Epoch: 9, Step: 355/5080
# Eval--Epoch: 9, Step: 356/5080
# Eval--Epoch: 9, Step: 357/5080
# Eval--Epoch: 9, Step: 358/5080
# Eval--Epoch: 9, Step: 359/5080
# Eval--Epoch: 9, Step: 360/5080
# Eval--Epoch: 9, Step: 361/5080
# Eval--Epoch: 9, Step: 362/5080
# Eval--Epoch: 9, Step: 363/5080
# Eval--Epoch: 9, Step: 364/5080
# Eval--Epoch: 9, Step: 365/5080
# Eval--Epoch: 9, Step: 366/5080
# Eval--Epoch: 9, Step: 367/5080
# Eval--Epoch: 9, Step: 368/5080
# Eval--Epoch: 9, Step: 369/5080
# Eval--Epoch: 9, Step: 370/5080
# Eval--Epoch: 9, Step: 371/5080
# Eval--Epoch: 9, Step: 372/5080
# Eval--Epoch: 9, Step: 373/5080
# Eval--Epoch: 9, Step: 374/5080
# Eval--Epoch: 9, Step: 375/5080
# Eval--Epoch: 9, Step: 376/5080
# Eval--Epoch: 9, Step: 377/5080
# Eval--Epoch: 9, Step: 378/5080
# Eval--Epoch: 9, Step: 379/5080
# Eval--Epoch: 9, Step: 380/5080
# Eval--Epoch: 9, Step: 381/5080
# Eval--Epoch: 9, Step: 382/5080
# Eval--Epoch: 9, Step: 383/5080
# Eval--Epoch: 9, Step: 384/5080
# Eval--Epoch: 9, Step: 385/5080
# Eval--Epoch: 9, Step: 386/5080
# Eval--Epoch: 9, Step: 387/5080
# Eval--Epoch: 9, Step: 388/5080
# Eval--Epoch: 9, Step: 389/5080
# Eval--Epoch: 9, Step: 390/5080
# Eval--Epoch: 9, Step: 391/5080
# Eval--Epoch: 9, Step: 392/5080
# Eval--Epoch: 9, Step: 393/5080
# Eval--Epoch: 9, Step: 394/5080
# Eval--Epoch: 9, Step: 395/5080
# Eval--Epoch: 9, Step: 396/5080
# Eval--Epoch: 9, Step: 397/5080
# Eval--Epoch: 9, Step: 398/5080
# Eval--Epoch: 9, Step: 399/5080
# Eval--Epoch: 9, Step: 400/5080
# Eval--Epoch: 9, Step: 401/5080
# Eval--Epoch: 9, Step: 402/5080
# Eval--Epoch: 9, Step: 403/5080
# Eval--Epoch: 9, Step: 404/5080
# Eval--Epoch: 9, Step: 405/5080
# Eval--Epoch: 9, Step: 406/5080
# Eval--Epoch: 9, Step: 407/5080
# Eval--Epoch: 9, Step: 408/5080
# Eval--Epoch: 9, Step: 409/5080
# Eval--Epoch: 9, Step: 410/5080
# Eval--Epoch: 9, Step: 411/5080
# Eval--Epoch: 9, Step: 412/5080
# Eval--Epoch: 9, Step: 413/5080
# Eval--Epoch: 9, Step: 414/5080
# Eval--Epoch: 9, Step: 415/5080
# Eval--Epoch: 9, Step: 416/5080
# Eval--Epoch: 9, Step: 417/5080
# Eval--Epoch: 9, Step: 418/5080
# Eval--Epoch: 9, Step: 419/5080
# Eval--Epoch: 9, Step: 420/5080
# Eval--Epoch: 9, Step: 421/5080
# Eval--Epoch: 9, Step: 422/5080
# Eval--Epoch: 9, Step: 423/5080
# Eval--Epoch: 9, Step: 424/5080
# Eval--Epoch: 9, Step: 425/5080
# Eval--Epoch: 9, Step: 426/5080
# Eval--Epoch: 9, Step: 427/5080
# Eval--Epoch: 9, Step: 428/5080
# Eval--Epoch: 9, Step: 429/5080
# Eval--Epoch: 9, Step: 430/5080
# Eval--Epoch: 9, Step: 431/5080
# Eval--Epoch: 9, Step: 432/5080
# Eval--Epoch: 9, Step: 433/5080
# Eval--Epoch: 9, Step: 434/5080
# Eval--Epoch: 9, Step: 435/5080
# Eval--Epoch: 9, Step: 436/5080
# Eval--Epoch: 9, Step: 437/5080
# Eval--Epoch: 9, Step: 438/5080
# Eval--Epoch: 9, Step: 439/5080
# Eval--Epoch: 9, Step: 440/5080
# Eval--Epoch: 9, Step: 441/5080
# Eval--Epoch: 9, Step: 442/5080
# Eval--Epoch: 9, Step: 443/5080
# Eval--Epoch: 9, Step: 444/5080
# Eval--Epoch: 9, Step: 445/5080
# Eval--Epoch: 9, Step: 446/5080
# Eval--Epoch: 9, Step: 447/5080
# Eval--Epoch: 9, Step: 448/5080
# Eval--Epoch: 9, Step: 449/5080
# Eval--Epoch: 9, Step: 450/5080
# Eval--Epoch: 9, Step: 451/5080
# Eval--Epoch: 9, Step: 452/5080
# Eval--Epoch: 9, Step: 453/5080
# Eval--Epoch: 9, Step: 454/5080
# Eval--Epoch: 9, Step: 455/5080
# Eval--Epoch: 9, Step: 456/5080
# Eval--Epoch: 9, Step: 457/5080
# Eval--Epoch: 9, Step: 458/5080
# Eval--Epoch: 9, Step: 459/5080
# Eval--Epoch: 9, Step: 460/5080
# Eval--Epoch: 9, Step: 461/5080
# Eval--Epoch: 9, Step: 462/5080
# Eval--Epoch: 9, Step: 463/5080
# Eval--Epoch: 9, Step: 464/5080
# Eval--Epoch: 9, Step: 465/5080
# Eval--Epoch: 9, Step: 466/5080
# Eval--Epoch: 9, Step: 467/5080
# Eval--Epoch: 9, Step: 468/5080
# Eval--Epoch: 9, Step: 469/5080
# Eval--Epoch: 9, Step: 470/5080
# Eval--Epoch: 9, Step: 471/5080
# Eval--Epoch: 9, Step: 472/5080
# Eval--Epoch: 9, Step: 473/5080
# Eval--Epoch: 9, Step: 474/5080
# Eval--Epoch: 9, Step: 475/5080
# Eval--Epoch: 9, Step: 476/5080
# Eval--Epoch: 9, Step: 477/5080
# Eval--Epoch: 9, Step: 478/5080
# Eval--Epoch: 9, Step: 479/5080
# Eval--Epoch: 9, Step: 480/5080
# Eval--Epoch: 9, Step: 481/5080
# Eval--Epoch: 9, Step: 482/5080
# Eval--Epoch: 9, Step: 483/5080
# Eval--Epoch: 9, Step: 484/5080
# Eval--Epoch: 9, Step: 485/5080
# Eval--Epoch: 9, Step: 486/5080
# Eval--Epoch: 9, Step: 487/5080
# Eval--Epoch: 9, Step: 488/5080
# Eval--Epoch: 9, Step: 489/5080
# Eval--Epoch: 9, Step: 490/5080
# Eval--Epoch: 9, Step: 491/5080
# Eval--Epoch: 9, Step: 492/5080
# Eval--Epoch: 9, Step: 493/5080
# Eval--Epoch: 9, Step: 494/5080
# Eval--Epoch: 9, Step: 495/5080
# Eval--Epoch: 9, Step: 496/5080
# Eval--Epoch: 9, Step: 497/5080
# Eval--Epoch: 9, Step: 498/5080
# Eval--Epoch: 9, Step: 499/5080
# Eval--Epoch: 9, Step: 500/5080
# Eval--Epoch: 9, Step: 501/5080
# Eval--Epoch: 9, Step: 502/5080
# Eval--Epoch: 9, Step: 503/5080
# Eval--Epoch: 9, Step: 504/5080
# Eval--Epoch: 9, Step: 505/5080
# Eval--Epoch: 9, Step: 506/5080
# Eval--Epoch: 9, Step: 507/5080
# Eval--Epoch: 9, Step: 508/5080
# Eval--Epoch: 9, Step: 509/5080
# Eval--Epoch: 9, Step: 510/5080
# Eval--Epoch: 9, Step: 511/5080
# Eval--Epoch: 9, Step: 512/5080
# Eval--Epoch: 9, Step: 513/5080
# Eval--Epoch: 9, Step: 514/5080
# Eval--Epoch: 9, Step: 515/5080
# Eval--Epoch: 9, Step: 516/5080
# Eval--Epoch: 9, Step: 517/5080
# Eval--Epoch: 9, Step: 518/5080
# Eval--Epoch: 9, Step: 519/5080
# Eval--Epoch: 9, Step: 520/5080
# Eval--Epoch: 9, Step: 521/5080
# Eval--Epoch: 9, Step: 522/5080
# Eval--Epoch: 9, Step: 523/5080
# Eval--Epoch: 9, Step: 524/5080
# Eval--Epoch: 9, Step: 525/5080
# Eval--Epoch: 9, Step: 526/5080
# Eval--Epoch: 9, Step: 527/5080
# Eval--Epoch: 9, Step: 528/5080
# Eval--Epoch: 9, Step: 529/5080
# Eval--Epoch: 9, Step: 530/5080
# Eval--Epoch: 9, Step: 531/5080
# Eval--Epoch: 9, Step: 532/5080
# Eval--Epoch: 9, Step: 533/5080
# Eval--Epoch: 9, Step: 534/5080
# Eval--Epoch: 9, Step: 535/5080
# Eval--Epoch: 9, Step: 536/5080
# Eval--Epoch: 9, Step: 537/5080
# Eval--Epoch: 9, Step: 538/5080
# Eval--Epoch: 9, Step: 539/5080
# Eval--Epoch: 9, Step: 540/5080
# Eval--Epoch: 9, Step: 541/5080
# Eval--Epoch: 9, Step: 542/5080
# Eval--Epoch: 9, Step: 543/5080
# Eval--Epoch: 9, Step: 544/5080
# Eval--Epoch: 9, Step: 545/5080
# Eval--Epoch: 9, Step: 546/5080
# Eval--Epoch: 9, Step: 547/5080
# Eval--Epoch: 9, Step: 548/5080
# Eval--Epoch: 9, Step: 549/5080
# Eval--Epoch: 9, Step: 550/5080
# Eval--Epoch: 9, Step: 551/5080
# Eval--Epoch: 9, Step: 552/5080
# Eval--Epoch: 9, Step: 553/5080
# Eval--Epoch: 9, Step: 554/5080
# Eval--Epoch: 9, Step: 555/5080
# Eval--Epoch: 9, Step: 556/5080
# Eval--Epoch: 9, Step: 557/5080
# Eval--Epoch: 9, Step: 558/5080
# Eval--Epoch: 9, Step: 559/5080
# Eval--Epoch: 9, Step: 560/5080
# Eval--Epoch: 9, Step: 561/5080
# Eval--Epoch: 9, Step: 562/5080
# Eval--Epoch: 9, Step: 563/5080
# Eval--Epoch: 9, Step: 564/5080
# Eval--Epoch: 9, Step: 565/5080
# Eval--Epoch: 9, Step: 566/5080
# Eval--Epoch: 9, Step: 567/5080
# Eval--Epoch: 9, Step: 568/5080
# Eval--Epoch: 9, Step: 569/5080
# Eval--Epoch: 9, Step: 570/5080
# Eval--Epoch: 9, Step: 571/5080
# Eval--Epoch: 9, Step: 572/5080
# Eval--Epoch: 9, Step: 573/5080
# Eval--Epoch: 9, Step: 574/5080
# Eval--Epoch: 9, Step: 575/5080
# Eval--Epoch: 9, Step: 576/5080
# Eval--Epoch: 9, Step: 577/5080
# Eval--Epoch: 9, Step: 578/5080
# Eval--Epoch: 9, Step: 579/5080
# Eval--Epoch: 9, Step: 580/5080
# Eval--Epoch: 9, Step: 581/5080
# Eval--Epoch: 9, Step: 582/5080
# Eval--Epoch: 9, Step: 583/5080
# Eval--Epoch: 9, Step: 584/5080
# Eval--Epoch: 9, Step: 585/5080
# Eval--Epoch: 9, Step: 586/5080
# Eval--Epoch: 9, Step: 587/5080
# Eval--Epoch: 9, Step: 588/5080
# Eval--Epoch: 9, Step: 589/5080
# Eval--Epoch: 9, Step: 590/5080
# Eval--Epoch: 9, Step: 591/5080
# Eval--Epoch: 9, Step: 592/5080
# Eval--Epoch: 9, Step: 593/5080
# Eval--Epoch: 9, Step: 594/5080
# Eval--Epoch: 9, Step: 595/5080
# Eval--Epoch: 9, Step: 596/5080
# Eval--Epoch: 9, Step: 597/5080
# Eval--Epoch: 9, Step: 598/5080
# Eval--Epoch: 9, Step: 599/5080
# Eval--Epoch: 9, Step: 600/5080
# Eval--Epoch: 9, Step: 601/5080
# Eval--Epoch: 9, Step: 602/5080
# Eval--Epoch: 9, Step: 603/5080
# Eval--Epoch: 9, Step: 604/5080
# Eval--Epoch: 9, Step: 605/5080
# Eval--Epoch: 9, Step: 606/5080
# Eval--Epoch: 9, Step: 607/5080
# Eval--Epoch: 9, Step: 608/5080
# Eval--Epoch: 9, Step: 609/5080
# Eval--Epoch: 9, Step: 610/5080
# Eval--Epoch: 9, Step: 611/5080
# Eval--Epoch: 9, Step: 612/5080
# Eval--Epoch: 9, Step: 613/5080
# Eval--Epoch: 9, Step: 614/5080
# Eval--Epoch: 9, Step: 615/5080
# Eval--Epoch: 9, Step: 616/5080
# Eval--Epoch: 9, Step: 617/5080
# Eval--Epoch: 9, Step: 618/5080
# Eval--Epoch: 9, Step: 619/5080
# Eval--Epoch: 9, Step: 620/5080
# Eval--Epoch: 9, Step: 621/5080
# Eval--Epoch: 9, Step: 622/5080
# Eval--Epoch: 9, Step: 623/5080
# Eval--Epoch: 9, Step: 624/5080
# Eval--Epoch: 9, Step: 625/5080
# Eval--Epoch: 9, Step: 626/5080
# Eval--Epoch: 9, Step: 627/5080
# Eval--Epoch: 9, Step: 628/5080
# Eval--Epoch: 9, Step: 629/5080
# Eval--Epoch: 9, Step: 630/5080
# Eval--Epoch: 9, Step: 631/5080
# Eval--Epoch: 9, Step: 632/5080
# Eval--Epoch: 9, Step: 633/5080
# Eval--Epoch: 9, Step: 634/5080
# Eval--Epoch: 9, Step: 635/5080
# Eval--Epoch: 9, Step: 636/5080
# Eval--Epoch: 9, Step: 637/5080
# Eval--Epoch: 9, Step: 638/5080
# Eval--Epoch: 9, Step: 639/5080
# Eval--Epoch: 9, Step: 640/5080
# Eval--Epoch: 9, Step: 641/5080
# Eval--Epoch: 9, Step: 642/5080
# Eval--Epoch: 9, Step: 643/5080
# Eval--Epoch: 9, Step: 644/5080
# Eval--Epoch: 9, Step: 645/5080
# Eval--Epoch: 9, Step: 646/5080
# Eval--Epoch: 9, Step: 647/5080
# Eval--Epoch: 9, Step: 648/5080
# Eval--Epoch: 9, Step: 649/5080
# Eval--Epoch: 9, Step: 650/5080
# Eval--Epoch: 9, Step: 651/5080
# Eval--Epoch: 9, Step: 652/5080
# Eval--Epoch: 9, Step: 653/5080
# Eval--Epoch: 9, Step: 654/5080
# Eval--Epoch: 9, Step: 655/5080
# Eval--Epoch: 9, Step: 656/5080
# Eval--Epoch: 9, Step: 657/5080
# Eval--Epoch: 9, Step: 658/5080
# Eval--Epoch: 9, Step: 659/5080
# Eval--Epoch: 9, Step: 660/5080
# Eval--Epoch: 9, Step: 661/5080
# Eval--Epoch: 9, Step: 662/5080
# Eval--Epoch: 9, Step: 663/5080
# Eval--Epoch: 9, Step: 664/5080
# Eval--Epoch: 9, Step: 665/5080
# Eval--Epoch: 9, Step: 666/5080
# Eval--Epoch: 9, Step: 667/5080
# Eval--Epoch: 9, Step: 668/5080
# Eval--Epoch: 9, Step: 669/5080
# Eval--Epoch: 9, Step: 670/5080
# Eval--Epoch: 9, Step: 671/5080
# Eval--Epoch: 9, Step: 672/5080
# Eval--Epoch: 9, Step: 673/5080
# Eval--Epoch: 9, Step: 674/5080
# Eval--Epoch: 9, Step: 675/5080
# Eval--Epoch: 9, Step: 676/5080
# Eval--Epoch: 9, Step: 677/5080
# Eval--Epoch: 9, Step: 678/5080
# Eval--Epoch: 9, Step: 679/5080
# Eval--Epoch: 9, Step: 680/5080
# Eval--Epoch: 9, Step: 681/5080
# Eval--Epoch: 9, Step: 682/5080
# Eval--Epoch: 9, Step: 683/5080
# Eval--Epoch: 9, Step: 684/5080
# Eval--Epoch: 9, Step: 685/5080
# Eval--Epoch: 9, Step: 686/5080
# Eval--Epoch: 9, Step: 687/5080
# Eval--Epoch: 9, Step: 688/5080
# Eval--Epoch: 9, Step: 689/5080
# Eval--Epoch: 9, Step: 690/5080
# Eval--Epoch: 9, Step: 691/5080
# Eval--Epoch: 9, Step: 692/5080
# Eval--Epoch: 9, Step: 693/5080
# Eval--Epoch: 9, Step: 694/5080
# Eval--Epoch: 9, Step: 695/5080
# Eval--Epoch: 9, Step: 696/5080
# Eval--Epoch: 9, Step: 697/5080
# Eval--Epoch: 9, Step: 698/5080
# Eval--Epoch: 9, Step: 699/5080
# Eval--Epoch: 9, Step: 700/5080
# Eval--Epoch: 9, Step: 701/5080
# Eval--Epoch: 9, Step: 702/5080
# Eval--Epoch: 9, Step: 703/5080
# Eval--Epoch: 9, Step: 704/5080
# Eval--Epoch: 9, Step: 705/5080
# Eval--Epoch: 9, Step: 706/5080
# Eval--Epoch: 9, Step: 707/5080
# Eval--Epoch: 9, Step: 708/5080
# Eval--Epoch: 9, Step: 709/5080
# Eval--Epoch: 9, Step: 710/5080
# Eval--Epoch: 9, Step: 711/5080
# Eval--Epoch: 9, Step: 712/5080
# Eval--Epoch: 9, Step: 713/5080
# Eval--Epoch: 9, Step: 714/5080
# Eval--Epoch: 9, Step: 715/5080
# Eval--Epoch: 9, Step: 716/5080
# Eval--Epoch: 9, Step: 717/5080
# Eval--Epoch: 9, Step: 718/5080
# Eval--Epoch: 9, Step: 719/5080
# Eval--Epoch: 9, Step: 720/5080
# Eval--Epoch: 9, Step: 721/5080
# Eval--Epoch: 9, Step: 722/5080
# Eval--Epoch: 9, Step: 723/5080
# Eval--Epoch: 9, Step: 724/5080
# Eval--Epoch: 9, Step: 725/5080
# Eval--Epoch: 9, Step: 726/5080
# Eval--Epoch: 9, Step: 727/5080
# Eval--Epoch: 9, Step: 728/5080
# Eval--Epoch: 9, Step: 729/5080
# Eval--Epoch: 9, Step: 730/5080
# Eval--Epoch: 9, Step: 731/5080
# Eval--Epoch: 9, Step: 732/5080
# Eval--Epoch: 9, Step: 733/5080
# Eval--Epoch: 9, Step: 734/5080
# Eval--Epoch: 9, Step: 735/5080
# Eval--Epoch: 9, Step: 736/5080
# Eval--Epoch: 9, Step: 737/5080
# Eval--Epoch: 9, Step: 738/5080
# Eval--Epoch: 9, Step: 739/5080
# Eval--Epoch: 9, Step: 740/5080
# Eval--Epoch: 9, Step: 741/5080
# Eval--Epoch: 9, Step: 742/5080
# Eval--Epoch: 9, Step: 743/5080
# Eval--Epoch: 9, Step: 744/5080
# Eval--Epoch: 9, Step: 745/5080
# Eval--Epoch: 9, Step: 746/5080
# Eval--Epoch: 9, Step: 747/5080
# Eval--Epoch: 9, Step: 748/5080
# Eval--Epoch: 9, Step: 749/5080
# Eval--Epoch: 9, Step: 750/5080
# Eval--Epoch: 9, Step: 751/5080
# Eval--Epoch: 9, Step: 752/5080
# Eval--Epoch: 9, Step: 753/5080
# Eval--Epoch: 9, Step: 754/5080
# Eval--Epoch: 9, Step: 755/5080
# Eval--Epoch: 9, Step: 756/5080
# Eval--Epoch: 9, Step: 757/5080
# Eval--Epoch: 9, Step: 758/5080
# Eval--Epoch: 9, Step: 759/5080
# Eval--Epoch: 9, Step: 760/5080
# Eval--Epoch: 9, Step: 761/5080
# Eval--Epoch: 9, Step: 762/5080
# Eval--Epoch: 9, Step: 763/5080
# Eval--Epoch: 9, Step: 764/5080
# Eval--Epoch: 9, Step: 765/5080
# Eval--Epoch: 9, Step: 766/5080
# Eval--Epoch: 9, Step: 767/5080
# Eval--Epoch: 9, Step: 768/5080
# Eval--Epoch: 9, Step: 769/5080
# Eval--Epoch: 9, Step: 770/5080
# Eval--Epoch: 9, Step: 771/5080
# Eval--Epoch: 9, Step: 772/5080
# Eval--Epoch: 9, Step: 773/5080
# Eval--Epoch: 9, Step: 774/5080
# Eval--Epoch: 9, Step: 775/5080
# Eval--Epoch: 9, Step: 776/5080
# Eval--Epoch: 9, Step: 777/5080
# Eval--Epoch: 9, Step: 778/5080
# Eval--Epoch: 9, Step: 779/5080
# Eval--Epoch: 9, Step: 780/5080
# Eval--Epoch: 9, Step: 781/5080
# Eval--Epoch: 9, Step: 782/5080
# Eval--Epoch: 9, Step: 783/5080
# Eval--Epoch: 9, Step: 784/5080
# Eval--Epoch: 9, Step: 785/5080
# Eval--Epoch: 9, Step: 786/5080
# Eval--Epoch: 9, Step: 787/5080
# Eval--Epoch: 9, Step: 788/5080
# Eval--Epoch: 9, Step: 789/5080
# Eval--Epoch: 9, Step: 790/5080
# Eval--Epoch: 9, Step: 791/5080
# Eval--Epoch: 9, Step: 792/5080
# Eval--Epoch: 9, Step: 793/5080
# Eval--Epoch: 9, Step: 794/5080
# Eval--Epoch: 9, Step: 795/5080
# Eval--Epoch: 9, Step: 796/5080
# Eval--Epoch: 9, Step: 797/5080
# Eval--Epoch: 9, Step: 798/5080
# Eval--Epoch: 9, Step: 799/5080
# Eval--Epoch: 9, Step: 800/5080
# Eval--Epoch: 9, Step: 801/5080
# Eval--Epoch: 9, Step: 802/5080
# Eval--Epoch: 9, Step: 803/5080
# Eval--Epoch: 9, Step: 804/5080
# Eval--Epoch: 9, Step: 805/5080
# Eval--Epoch: 9, Step: 806/5080
# Eval--Epoch: 9, Step: 807/5080
# Eval--Epoch: 9, Step: 808/5080
# Eval--Epoch: 9, Step: 809/5080
# Eval--Epoch: 9, Step: 810/5080
# Eval--Epoch: 9, Step: 811/5080
# Eval--Epoch: 9, Step: 812/5080
# Eval--Epoch: 9, Step: 813/5080
# Eval--Epoch: 9, Step: 814/5080
# Eval--Epoch: 9, Step: 815/5080
# Eval--Epoch: 9, Step: 816/5080
# Eval--Epoch: 9, Step: 817/5080
# Eval--Epoch: 9, Step: 818/5080
# Eval--Epoch: 9, Step: 819/5080
# Eval--Epoch: 9, Step: 820/5080
# Eval--Epoch: 9, Step: 821/5080
# Eval--Epoch: 9, Step: 822/5080
# Eval--Epoch: 9, Step: 823/5080
# Eval--Epoch: 9, Step: 824/5080
# Eval--Epoch: 9, Step: 825/5080
# Eval--Epoch: 9, Step: 826/5080
# Eval--Epoch: 9, Step: 827/5080
# Eval--Epoch: 9, Step: 828/5080
# Eval--Epoch: 9, Step: 829/5080
# Eval--Epoch: 9, Step: 830/5080
# Eval--Epoch: 9, Step: 831/5080
# Eval--Epoch: 9, Step: 832/5080
# Eval--Epoch: 9, Step: 833/5080
# Eval--Epoch: 9, Step: 834/5080
# Eval--Epoch: 9, Step: 835/5080
# Eval--Epoch: 9, Step: 836/5080
# Eval--Epoch: 9, Step: 837/5080
# Eval--Epoch: 9, Step: 838/5080
# Eval--Epoch: 9, Step: 839/5080
# Eval--Epoch: 9, Step: 840/5080
# Eval--Epoch: 9, Step: 841/5080
# Eval--Epoch: 9, Step: 842/5080
# Eval--Epoch: 9, Step: 843/5080
# Eval--Epoch: 9, Step: 844/5080
# Eval--Epoch: 9, Step: 845/5080
# Eval--Epoch: 9, Step: 846/5080
# Eval--Epoch: 9, Step: 847/5080
# Eval--Epoch: 9, Step: 848/5080
# Eval--Epoch: 9, Step: 849/5080
# Eval--Epoch: 9, Step: 850/5080
# Eval--Epoch: 9, Step: 851/5080
# Eval--Epoch: 9, Step: 852/5080
# Eval--Epoch: 9, Step: 853/5080
# Eval--Epoch: 9, Step: 854/5080
# Eval--Epoch: 9, Step: 855/5080
# Eval--Epoch: 9, Step: 856/5080
# Eval--Epoch: 9, Step: 857/5080
# Eval--Epoch: 9, Step: 858/5080
# Eval--Epoch: 9, Step: 859/5080
# Eval--Epoch: 9, Step: 860/5080
# Eval--Epoch: 9, Step: 861/5080
# Eval--Epoch: 9, Step: 862/5080
# Eval--Epoch: 9, Step: 863/5080
# Eval--Epoch: 9, Step: 864/5080
# Eval--Epoch: 9, Step: 865/5080
# Eval--Epoch: 9, Step: 866/5080
# Eval--Epoch: 9, Step: 867/5080
# Eval--Epoch: 9, Step: 868/5080
# Eval--Epoch: 9, Step: 869/5080
# Eval--Epoch: 9, Step: 870/5080
# Eval--Epoch: 9, Step: 871/5080
# Eval--Epoch: 9, Step: 872/5080
# Eval--Epoch: 9, Step: 873/5080
# Eval--Epoch: 9, Step: 874/5080
# Eval--Epoch: 9, Step: 875/5080
# Eval--Epoch: 9, Step: 876/5080
# Eval--Epoch: 9, Step: 877/5080
# Eval--Epoch: 9, Step: 878/5080
# Eval--Epoch: 9, Step: 879/5080
# Eval--Epoch: 9, Step: 880/5080
# Eval--Epoch: 9, Step: 881/5080
# Eval--Epoch: 9, Step: 882/5080
# Eval--Epoch: 9, Step: 883/5080
# Eval--Epoch: 9, Step: 884/5080
# Eval--Epoch: 9, Step: 885/5080
# Eval--Epoch: 9, Step: 886/5080
# Eval--Epoch: 9, Step: 887/5080
# Eval--Epoch: 9, Step: 888/5080
# Eval--Epoch: 9, Step: 889/5080
# Eval--Epoch: 9, Step: 890/5080
# Eval--Epoch: 9, Step: 891/5080
# Eval--Epoch: 9, Step: 892/5080
# Eval--Epoch: 9, Step: 893/5080
# Eval--Epoch: 9, Step: 894/5080
# Eval--Epoch: 9, Step: 895/5080
# Eval--Epoch: 9, Step: 896/5080
# Eval--Epoch: 9, Step: 897/5080
# Eval--Epoch: 9, Step: 898/5080
# Eval--Epoch: 9, Step: 899/5080
# Eval--Epoch: 9, Step: 900/5080
# Eval--Epoch: 9, Step: 901/5080
# Eval--Epoch: 9, Step: 902/5080
# Eval--Epoch: 9, Step: 903/5080
# Eval--Epoch: 9, Step: 904/5080
# Eval--Epoch: 9, Step: 905/5080
# Eval--Epoch: 9, Step: 906/5080
# Eval--Epoch: 9, Step: 907/5080
# Eval--Epoch: 9, Step: 908/5080
# Eval--Epoch: 9, Step: 909/5080
# Eval--Epoch: 9, Step: 910/5080
# Eval--Epoch: 9, Step: 911/5080
# Eval--Epoch: 9, Step: 912/5080
# Eval--Epoch: 9, Step: 913/5080
# Eval--Epoch: 9, Step: 914/5080
# Eval--Epoch: 9, Step: 915/5080
# Eval--Epoch: 9, Step: 916/5080
# Eval--Epoch: 9, Step: 917/5080
# Eval--Epoch: 9, Step: 918/5080
# Eval--Epoch: 9, Step: 919/5080
# Eval--Epoch: 9, Step: 920/5080
# Eval--Epoch: 9, Step: 921/5080
# Eval--Epoch: 9, Step: 922/5080
# Eval--Epoch: 9, Step: 923/5080
# Eval--Epoch: 9, Step: 924/5080
# Eval--Epoch: 9, Step: 925/5080
# Eval--Epoch: 9, Step: 926/5080
# Eval--Epoch: 9, Step: 927/5080
# Eval--Epoch: 9, Step: 928/5080
# Eval--Epoch: 9, Step: 929/5080
# Eval--Epoch: 9, Step: 930/5080
# Eval--Epoch: 9, Step: 931/5080
# Eval--Epoch: 9, Step: 932/5080
# Eval--Epoch: 9, Step: 933/5080
# Eval--Epoch: 9, Step: 934/5080
# Eval--Epoch: 9, Step: 935/5080
# Eval--Epoch: 9, Step: 936/5080
# Eval--Epoch: 9, Step: 937/5080
# Eval--Epoch: 9, Step: 938/5080
# Eval--Epoch: 9, Step: 939/5080
# Eval--Epoch: 9, Step: 940/5080
# Eval--Epoch: 9, Step: 941/5080
# Eval--Epoch: 9, Step: 942/5080
# Eval--Epoch: 9, Step: 943/5080
# Eval--Epoch: 9, Step: 944/5080
# Eval--Epoch: 9, Step: 945/5080
# Eval--Epoch: 9, Step: 946/5080
# Eval--Epoch: 9, Step: 947/5080
# Eval--Epoch: 9, Step: 948/5080
# Eval--Epoch: 9, Step: 949/5080
# Eval--Epoch: 9, Step: 950/5080
# Eval--Epoch: 9, Step: 951/5080
# Eval--Epoch: 9, Step: 952/5080
# Eval--Epoch: 9, Step: 953/5080
# Eval--Epoch: 9, Step: 954/5080
# Eval--Epoch: 9, Step: 955/5080
# Eval--Epoch: 9, Step: 956/5080
# Eval--Epoch: 9, Step: 957/5080
# Eval--Epoch: 9, Step: 958/5080
# Eval--Epoch: 9, Step: 959/5080
# Eval--Epoch: 9, Step: 960/5080
# Eval--Epoch: 9, Step: 961/5080
# Eval--Epoch: 9, Step: 962/5080
# Eval--Epoch: 9, Step: 963/5080
# Eval--Epoch: 9, Step: 964/5080
# Eval--Epoch: 9, Step: 965/5080
# Eval--Epoch: 9, Step: 966/5080
# Eval--Epoch: 9, Step: 967/5080
# Eval--Epoch: 9, Step: 968/5080
# Eval--Epoch: 9, Step: 969/5080
# Eval--Epoch: 9, Step: 970/5080
# Eval--Epoch: 9, Step: 971/5080
# Eval--Epoch: 9, Step: 972/5080
# Eval--Epoch: 9, Step: 973/5080
# Eval--Epoch: 9, Step: 974/5080
# Eval--Epoch: 9, Step: 975/5080
# Eval--Epoch: 9, Step: 976/5080
# Eval--Epoch: 9, Step: 977/5080
# Eval--Epoch: 9, Step: 978/5080
# Eval--Epoch: 9, Step: 979/5080
# Eval--Epoch: 9, Step: 980/5080
# Eval--Epoch: 9, Step: 981/5080
# Eval--Epoch: 9, Step: 982/5080
# Eval--Epoch: 9, Step: 983/5080
# Eval--Epoch: 9, Step: 984/5080
# Eval--Epoch: 9, Step: 985/5080
# Eval--Epoch: 9, Step: 986/5080
# Eval--Epoch: 9, Step: 987/5080
# Eval--Epoch: 9, Step: 988/5080
# Eval--Epoch: 9, Step: 989/5080
# Eval--Epoch: 9, Step: 990/5080
# Eval--Epoch: 9, Step: 991/5080
# Eval--Epoch: 9, Step: 992/5080
# Eval--Epoch: 9, Step: 993/5080
# Eval--Epoch: 9, Step: 994/5080
# Eval--Epoch: 9, Step: 995/5080
# Eval--Epoch: 9, Step: 996/5080
# Eval--Epoch: 9, Step: 997/5080
# Eval--Epoch: 9, Step: 998/5080
# Eval--Epoch: 9, Step: 999/5080
# Eval--Epoch: 9, Step: 1000/5080
# Eval--Epoch: 9, Step: 1001/5080
# Eval--Epoch: 9, Step: 1002/5080
# Eval--Epoch: 9, Step: 1003/5080
# Eval--Epoch: 9, Step: 1004/5080
# Eval--Epoch: 9, Step: 1005/5080
# Eval--Epoch: 9, Step: 1006/5080
# Eval--Epoch: 9, Step: 1007/5080
# Eval--Epoch: 9, Step: 1008/5080
# Eval--Epoch: 9, Step: 1009/5080
# Eval--Epoch: 9, Step: 1010/5080
# Eval--Epoch: 9, Step: 1011/5080
# Eval--Epoch: 9, Step: 1012/5080
# Eval--Epoch: 9, Step: 1013/5080
# Eval--Epoch: 9, Step: 1014/5080
# Eval--Epoch: 9, Step: 1015/5080
# Eval--Epoch: 9, Step: 1016/5080
# Eval--Epoch: 9, Step: 1017/5080
# Eval--Epoch: 9, Step: 1018/5080
# Eval--Epoch: 9, Step: 1019/5080
# Eval--Epoch: 9, Step: 1020/5080
# Eval--Epoch: 9, Step: 1021/5080
# Eval--Epoch: 9, Step: 1022/5080
# Eval--Epoch: 9, Step: 1023/5080
# Eval--Epoch: 9, Step: 1024/5080
# Eval--Epoch: 9, Step: 1025/5080
# Eval--Epoch: 9, Step: 1026/5080
# Eval--Epoch: 9, Step: 1027/5080
# Eval--Epoch: 9, Step: 1028/5080
# Eval--Epoch: 9, Step: 1029/5080
# Eval--Epoch: 9, Step: 1030/5080
# Eval--Epoch: 9, Step: 1031/5080
# Eval--Epoch: 9, Step: 1032/5080
# Eval--Epoch: 9, Step: 1033/5080
# Eval--Epoch: 9, Step: 1034/5080
# Eval--Epoch: 9, Step: 1035/5080
# Eval--Epoch: 9, Step: 1036/5080
# Eval--Epoch: 9, Step: 1037/5080
# Eval--Epoch: 9, Step: 1038/5080
# Eval--Epoch: 9, Step: 1039/5080
# Eval--Epoch: 9, Step: 1040/5080
# Eval--Epoch: 9, Step: 1041/5080
# Eval--Epoch: 9, Step: 1042/5080
# Eval--Epoch: 9, Step: 1043/5080
# Eval--Epoch: 9, Step: 1044/5080
# Eval--Epoch: 9, Step: 1045/5080
# Eval--Epoch: 9, Step: 1046/5080
# Eval--Epoch: 9, Step: 1047/5080
# Eval--Epoch: 9, Step: 1048/5080
# Eval--Epoch: 9, Step: 1049/5080
# Eval--Epoch: 9, Step: 1050/5080
# Eval--Epoch: 9, Step: 1051/5080
# Eval--Epoch: 9, Step: 1052/5080
# Eval--Epoch: 9, Step: 1053/5080
# Eval--Epoch: 9, Step: 1054/5080
# Eval--Epoch: 9, Step: 1055/5080
# Eval--Epoch: 9, Step: 1056/5080
# Eval--Epoch: 9, Step: 1057/5080
# Eval--Epoch: 9, Step: 1058/5080
# Eval--Epoch: 9, Step: 1059/5080
# Eval--Epoch: 9, Step: 1060/5080
# Eval--Epoch: 9, Step: 1061/5080
# Eval--Epoch: 9, Step: 1062/5080
# Eval--Epoch: 9, Step: 1063/5080
# Eval--Epoch: 9, Step: 1064/5080
# Eval--Epoch: 9, Step: 1065/5080
# Eval--Epoch: 9, Step: 1066/5080
# Eval--Epoch: 9, Step: 1067/5080
# Eval--Epoch: 9, Step: 1068/5080
# Eval--Epoch: 9, Step: 1069/5080
# Eval--Epoch: 9, Step: 1070/5080
# Eval--Epoch: 9, Step: 1071/5080
# Eval--Epoch: 9, Step: 1072/5080
# Eval--Epoch: 9, Step: 1073/5080
# Eval--Epoch: 9, Step: 1074/5080
# Eval--Epoch: 9, Step: 1075/5080
# Eval--Epoch: 9, Step: 1076/5080
# Eval--Epoch: 9, Step: 1077/5080
# Eval--Epoch: 9, Step: 1078/5080
# Eval--Epoch: 9, Step: 1079/5080
# Eval--Epoch: 9, Step: 1080/5080
# Eval--Epoch: 9, Step: 1081/5080
# Eval--Epoch: 9, Step: 1082/5080
# Eval--Epoch: 9, Step: 1083/5080
# Eval--Epoch: 9, Step: 1084/5080
# Eval--Epoch: 9, Step: 1085/5080
# Eval--Epoch: 9, Step: 1086/5080
# Eval--Epoch: 9, Step: 1087/5080
# Eval--Epoch: 9, Step: 1088/5080
# Eval--Epoch: 9, Step: 1089/5080
# Eval--Epoch: 9, Step: 1090/5080
# Eval--Epoch: 9, Step: 1091/5080
# Eval--Epoch: 9, Step: 1092/5080
# Eval--Epoch: 9, Step: 1093/5080
# Eval--Epoch: 9, Step: 1094/5080
# Eval--Epoch: 9, Step: 1095/5080
# Eval--Epoch: 9, Step: 1096/5080
# Eval--Epoch: 9, Step: 1097/5080
# Eval--Epoch: 9, Step: 1098/5080
# Eval--Epoch: 9, Step: 1099/5080
# Eval--Epoch: 9, Step: 1100/5080
# Eval--Epoch: 9, Step: 1101/5080
# Eval--Epoch: 9, Step: 1102/5080
# Eval--Epoch: 9, Step: 1103/5080
# Eval--Epoch: 9, Step: 1104/5080
# Eval--Epoch: 9, Step: 1105/5080
# Eval--Epoch: 9, Step: 1106/5080
# Eval--Epoch: 9, Step: 1107/5080
# Eval--Epoch: 9, Step: 1108/5080
# Eval--Epoch: 9, Step: 1109/5080
# Eval--Epoch: 9, Step: 1110/5080
# Eval--Epoch: 9, Step: 1111/5080
# Eval--Epoch: 9, Step: 1112/5080
# Eval--Epoch: 9, Step: 1113/5080
# Eval--Epoch: 9, Step: 1114/5080
# Eval--Epoch: 9, Step: 1115/5080
# Eval--Epoch: 9, Step: 1116/5080
# Eval--Epoch: 9, Step: 1117/5080
# Eval--Epoch: 9, Step: 1118/5080
# Eval--Epoch: 9, Step: 1119/5080
# Eval--Epoch: 9, Step: 1120/5080
# Eval--Epoch: 9, Step: 1121/5080
# Eval--Epoch: 9, Step: 1122/5080
# Eval--Epoch: 9, Step: 1123/5080
# Eval--Epoch: 9, Step: 1124/5080
# Eval--Epoch: 9, Step: 1125/5080
# Eval--Epoch: 9, Step: 1126/5080
# Eval--Epoch: 9, Step: 1127/5080
# Eval--Epoch: 9, Step: 1128/5080
# Eval--Epoch: 9, Step: 1129/5080
# Eval--Epoch: 9, Step: 1130/5080
# Eval--Epoch: 9, Step: 1131/5080
# Eval--Epoch: 9, Step: 1132/5080
# Eval--Epoch: 9, Step: 1133/5080
# Eval--Epoch: 9, Step: 1134/5080
# Eval--Epoch: 9, Step: 1135/5080
# Eval--Epoch: 9, Step: 1136/5080
# Eval--Epoch: 9, Step: 1137/5080
# Eval--Epoch: 9, Step: 1138/5080
# Eval--Epoch: 9, Step: 1139/5080
# Eval--Epoch: 9, Step: 1140/5080
# Eval--Epoch: 9, Step: 1141/5080
# Eval--Epoch: 9, Step: 1142/5080
# Eval--Epoch: 9, Step: 1143/5080
# Eval--Epoch: 9, Step: 1144/5080
# Eval--Epoch: 9, Step: 1145/5080
# Eval--Epoch: 9, Step: 1146/5080
# Eval--Epoch: 9, Step: 1147/5080
# Eval--Epoch: 9, Step: 1148/5080
# Eval--Epoch: 9, Step: 1149/5080
# Eval--Epoch: 9, Step: 1150/5080
# Eval--Epoch: 9, Step: 1151/5080
# Eval--Epoch: 9, Step: 1152/5080
# Eval--Epoch: 9, Step: 1153/5080
# Eval--Epoch: 9, Step: 1154/5080
# Eval--Epoch: 9, Step: 1155/5080
# Eval--Epoch: 9, Step: 1156/5080
# Eval--Epoch: 9, Step: 1157/5080
# Eval--Epoch: 9, Step: 1158/5080
# Eval--Epoch: 9, Step: 1159/5080
# Eval--Epoch: 9, Step: 1160/5080
# Eval--Epoch: 9, Step: 1161/5080
# Eval--Epoch: 9, Step: 1162/5080
# Eval--Epoch: 9, Step: 1163/5080
# Eval--Epoch: 9, Step: 1164/5080
# Eval--Epoch: 9, Step: 1165/5080
# Eval--Epoch: 9, Step: 1166/5080
# Eval--Epoch: 9, Step: 1167/5080
# Eval--Epoch: 9, Step: 1168/5080
# Eval--Epoch: 9, Step: 1169/5080
# Eval--Epoch: 9, Step: 1170/5080
# Eval--Epoch: 9, Step: 1171/5080
# Eval--Epoch: 9, Step: 1172/5080
# Eval--Epoch: 9, Step: 1173/5080
# Eval--Epoch: 9, Step: 1174/5080
# Eval--Epoch: 9, Step: 1175/5080
# Eval--Epoch: 9, Step: 1176/5080
# Eval--Epoch: 9, Step: 1177/5080
# Eval--Epoch: 9, Step: 1178/5080
# Eval--Epoch: 9, Step: 1179/5080
# Eval--Epoch: 9, Step: 1180/5080
# Eval--Epoch: 9, Step: 1181/5080
# Eval--Epoch: 9, Step: 1182/5080
# Eval--Epoch: 9, Step: 1183/5080
# Eval--Epoch: 9, Step: 1184/5080
# Eval--Epoch: 9, Step: 1185/5080
# Eval--Epoch: 9, Step: 1186/5080
# Eval--Epoch: 9, Step: 1187/5080
# Eval--Epoch: 9, Step: 1188/5080
# Eval--Epoch: 9, Step: 1189/5080
# Eval--Epoch: 9, Step: 1190/5080
# Eval--Epoch: 9, Step: 1191/5080
# Eval--Epoch: 9, Step: 1192/5080
# Eval--Epoch: 9, Step: 1193/5080
# Eval--Epoch: 9, Step: 1194/5080
# Eval--Epoch: 9, Step: 1195/5080
# Eval--Epoch: 9, Step: 1196/5080
# Eval--Epoch: 9, Step: 1197/5080
# Eval--Epoch: 9, Step: 1198/5080
# Eval--Epoch: 9, Step: 1199/5080
# Eval--Epoch: 9, Step: 1200/5080
# Eval--Epoch: 9, Step: 1201/5080
# Eval--Epoch: 9, Step: 1202/5080
# Eval--Epoch: 9, Step: 1203/5080
# Eval--Epoch: 9, Step: 1204/5080
# Eval--Epoch: 9, Step: 1205/5080
# Eval--Epoch: 9, Step: 1206/5080
# Eval--Epoch: 9, Step: 1207/5080
# Eval--Epoch: 9, Step: 1208/5080
# Eval--Epoch: 9, Step: 1209/5080
# Eval--Epoch: 9, Step: 1210/5080
# Eval--Epoch: 9, Step: 1211/5080
# Eval--Epoch: 9, Step: 1212/5080
# Eval--Epoch: 9, Step: 1213/5080
# Eval--Epoch: 9, Step: 1214/5080
# Eval--Epoch: 9, Step: 1215/5080
# Eval--Epoch: 9, Step: 1216/5080
# Eval--Epoch: 9, Step: 1217/5080
# Eval--Epoch: 9, Step: 1218/5080
# Eval--Epoch: 9, Step: 1219/5080
# Eval--Epoch: 9, Step: 1220/5080
# Eval--Epoch: 9, Step: 1221/5080
# Eval--Epoch: 9, Step: 1222/5080
# Eval--Epoch: 9, Step: 1223/5080
# Eval--Epoch: 9, Step: 1224/5080
# Eval--Epoch: 9, Step: 1225/5080
# Eval--Epoch: 9, Step: 1226/5080
# Eval--Epoch: 9, Step: 1227/5080
# Eval--Epoch: 9, Step: 1228/5080
# Eval--Epoch: 9, Step: 1229/5080
# Eval--Epoch: 9, Step: 1230/5080
# Eval--Epoch: 9, Step: 1231/5080
# Eval--Epoch: 9, Step: 1232/5080
# Eval--Epoch: 9, Step: 1233/5080
# Eval--Epoch: 9, Step: 1234/5080
# Eval--Epoch: 9, Step: 1235/5080
# Eval--Epoch: 9, Step: 1236/5080
# Eval--Epoch: 9, Step: 1237/5080
# Eval--Epoch: 9, Step: 1238/5080
# Eval--Epoch: 9, Step: 1239/5080
# Eval--Epoch: 9, Step: 1240/5080
# Eval--Epoch: 9, Step: 1241/5080
# Eval--Epoch: 9, Step: 1242/5080
# Eval--Epoch: 9, Step: 1243/5080
# Eval--Epoch: 9, Step: 1244/5080
# Eval--Epoch: 9, Step: 1245/5080
# Eval--Epoch: 9, Step: 1246/5080
# Eval--Epoch: 9, Step: 1247/5080
# Eval--Epoch: 9, Step: 1248/5080
# Eval--Epoch: 9, Step: 1249/5080
# Eval--Epoch: 9, Step: 1250/5080
# Eval--Epoch: 9, Step: 1251/5080
# Eval--Epoch: 9, Step: 1252/5080
# Eval--Epoch: 9, Step: 1253/5080
# Eval--Epoch: 9, Step: 1254/5080
# Eval--Epoch: 9, Step: 1255/5080
# Eval--Epoch: 9, Step: 1256/5080
# Eval--Epoch: 9, Step: 1257/5080
# Eval--Epoch: 9, Step: 1258/5080
# Eval--Epoch: 9, Step: 1259/5080
# Eval--Epoch: 9, Step: 1260/5080
# Eval--Epoch: 9, Step: 1261/5080
# Eval--Epoch: 9, Step: 1262/5080
# Eval--Epoch: 9, Step: 1263/5080
# Eval--Epoch: 9, Step: 1264/5080
# Eval--Epoch: 9, Step: 1265/5080
# Eval--Epoch: 9, Step: 1266/5080
# Eval--Epoch: 9, Step: 1267/5080
# Eval--Epoch: 9, Step: 1268/5080
# Eval--Epoch: 9, Step: 1269/5080
# Eval--Epoch: 9, Step: 1270/5080
# Eval--Epoch: 9, Step: 1271/5080
# Eval--Epoch: 9, Step: 1272/5080
# Eval--Epoch: 9, Step: 1273/5080
# Eval--Epoch: 9, Step: 1274/5080
# Eval--Epoch: 9, Step: 1275/5080
# Eval--Epoch: 9, Step: 1276/5080
# Eval--Epoch: 9, Step: 1277/5080
# Eval--Epoch: 9, Step: 1278/5080
# Eval--Epoch: 9, Step: 1279/5080
# Eval--Epoch: 9, Step: 1280/5080
# Eval--Epoch: 9, Step: 1281/5080
# Eval--Epoch: 9, Step: 1282/5080
# Eval--Epoch: 9, Step: 1283/5080
# Eval--Epoch: 9, Step: 1284/5080
# Eval--Epoch: 9, Step: 1285/5080
# Eval--Epoch: 9, Step: 1286/5080
# Eval--Epoch: 9, Step: 1287/5080
# Eval--Epoch: 9, Step: 1288/5080
# Eval--Epoch: 9, Step: 1289/5080
# Eval--Epoch: 9, Step: 1290/5080
# Eval--Epoch: 9, Step: 1291/5080
# Eval--Epoch: 9, Step: 1292/5080
# Eval--Epoch: 9, Step: 1293/5080
# Eval--Epoch: 9, Step: 1294/5080
# Eval--Epoch: 9, Step: 1295/5080
# Eval--Epoch: 9, Step: 1296/5080
# Eval--Epoch: 9, Step: 1297/5080
# Eval--Epoch: 9, Step: 1298/5080
# Eval--Epoch: 9, Step: 1299/5080
# Eval--Epoch: 9, Step: 1300/5080
# Eval--Epoch: 9, Step: 1301/5080
# Eval--Epoch: 9, Step: 1302/5080
# Eval--Epoch: 9, Step: 1303/5080
# Eval--Epoch: 9, Step: 1304/5080
# Eval--Epoch: 9, Step: 1305/5080
# Eval--Epoch: 9, Step: 1306/5080
# Eval--Epoch: 9, Step: 1307/5080
# Eval--Epoch: 9, Step: 1308/5080
# Eval--Epoch: 9, Step: 1309/5080
# Eval--Epoch: 9, Step: 1310/5080
# Eval--Epoch: 9, Step: 1311/5080
# Eval--Epoch: 9, Step: 1312/5080
# Eval--Epoch: 9, Step: 1313/5080
# Eval--Epoch: 9, Step: 1314/5080
# Eval--Epoch: 9, Step: 1315/5080
# Eval--Epoch: 9, Step: 1316/5080
# Eval--Epoch: 9, Step: 1317/5080
# Eval--Epoch: 9, Step: 1318/5080
# Eval--Epoch: 9, Step: 1319/5080
# Eval--Epoch: 9, Step: 1320/5080
# Eval--Epoch: 9, Step: 1321/5080
# Eval--Epoch: 9, Step: 1322/5080
# Eval--Epoch: 9, Step: 1323/5080
# Eval--Epoch: 9, Step: 1324/5080
# Eval--Epoch: 9, Step: 1325/5080
# Eval--Epoch: 9, Step: 1326/5080
# Eval--Epoch: 9, Step: 1327/5080
# Eval--Epoch: 9, Step: 1328/5080
# Eval--Epoch: 9, Step: 1329/5080
# Eval--Epoch: 9, Step: 1330/5080
# Eval--Epoch: 9, Step: 1331/5080
# Eval--Epoch: 9, Step: 1332/5080
# Eval--Epoch: 9, Step: 1333/5080
# Eval--Epoch: 9, Step: 1334/5080
# Eval--Epoch: 9, Step: 1335/5080
# Eval--Epoch: 9, Step: 1336/5080
# Eval--Epoch: 9, Step: 1337/5080
# Eval--Epoch: 9, Step: 1338/5080
# Eval--Epoch: 9, Step: 1339/5080
# Eval--Epoch: 9, Step: 1340/5080
# Eval--Epoch: 9, Step: 1341/5080
# Eval--Epoch: 9, Step: 1342/5080
# Eval--Epoch: 9, Step: 1343/5080
# Eval--Epoch: 9, Step: 1344/5080
# Eval--Epoch: 9, Step: 1345/5080
# Eval--Epoch: 9, Step: 1346/5080
# Eval--Epoch: 9, Step: 1347/5080
# Eval--Epoch: 9, Step: 1348/5080
# Eval--Epoch: 9, Step: 1349/5080
# Eval--Epoch: 9, Step: 1350/5080
# Eval--Epoch: 9, Step: 1351/5080
# Eval--Epoch: 9, Step: 1352/5080
# Eval--Epoch: 9, Step: 1353/5080
# Eval--Epoch: 9, Step: 1354/5080
# Eval--Epoch: 9, Step: 1355/5080
# Eval--Epoch: 9, Step: 1356/5080
# Eval--Epoch: 9, Step: 1357/5080
# Eval--Epoch: 9, Step: 1358/5080
# Eval--Epoch: 9, Step: 1359/5080
# Eval--Epoch: 9, Step: 1360/5080
# Eval--Epoch: 9, Step: 1361/5080
# Eval--Epoch: 9, Step: 1362/5080
# Eval--Epoch: 9, Step: 1363/5080
# Eval--Epoch: 9, Step: 1364/5080
# Eval--Epoch: 9, Step: 1365/5080
# Eval--Epoch: 9, Step: 1366/5080
# Eval--Epoch: 9, Step: 1367/5080
# Eval--Epoch: 9, Step: 1368/5080
# Eval--Epoch: 9, Step: 1369/5080
# Eval--Epoch: 9, Step: 1370/5080
# Eval--Epoch: 9, Step: 1371/5080
# Eval--Epoch: 9, Step: 1372/5080
# Eval--Epoch: 9, Step: 1373/5080
# Eval--Epoch: 9, Step: 1374/5080
# Eval--Epoch: 9, Step: 1375/5080
# Eval--Epoch: 9, Step: 1376/5080
# Eval--Epoch: 9, Step: 1377/5080
# Eval--Epoch: 9, Step: 1378/5080
# Eval--Epoch: 9, Step: 1379/5080
# Eval--Epoch: 9, Step: 1380/5080
# Eval--Epoch: 9, Step: 1381/5080
# Eval--Epoch: 9, Step: 1382/5080
# Eval--Epoch: 9, Step: 1383/5080
# Eval--Epoch: 9, Step: 1384/5080
# Eval--Epoch: 9, Step: 1385/5080
# Eval--Epoch: 9, Step: 1386/5080
# Eval--Epoch: 9, Step: 1387/5080
# Eval--Epoch: 9, Step: 1388/5080
# Eval--Epoch: 9, Step: 1389/5080
# Eval--Epoch: 9, Step: 1390/5080
# Eval--Epoch: 9, Step: 1391/5080
# Eval--Epoch: 9, Step: 1392/5080
# Eval--Epoch: 9, Step: 1393/5080
# Eval--Epoch: 9, Step: 1394/5080
# Eval--Epoch: 9, Step: 1395/5080
# Eval--Epoch: 9, Step: 1396/5080
# Eval--Epoch: 9, Step: 1397/5080
# Eval--Epoch: 9, Step: 1398/5080
# Eval--Epoch: 9, Step: 1399/5080
# Eval--Epoch: 9, Step: 1400/5080
# Eval--Epoch: 9, Step: 1401/5080
# Eval--Epoch: 9, Step: 1402/5080
# Eval--Epoch: 9, Step: 1403/5080
# Eval--Epoch: 9, Step: 1404/5080
# Eval--Epoch: 9, Step: 1405/5080
# Eval--Epoch: 9, Step: 1406/5080
# Eval--Epoch: 9, Step: 1407/5080
# Eval--Epoch: 9, Step: 1408/5080
# Eval--Epoch: 9, Step: 1409/5080
# Eval--Epoch: 9, Step: 1410/5080
# Eval--Epoch: 9, Step: 1411/5080
# Eval--Epoch: 9, Step: 1412/5080
# Eval--Epoch: 9, Step: 1413/5080
# Eval--Epoch: 9, Step: 1414/5080
# Eval--Epoch: 9, Step: 1415/5080
# Eval--Epoch: 9, Step: 1416/5080
# Eval--Epoch: 9, Step: 1417/5080
# Eval--Epoch: 9, Step: 1418/5080
# Eval--Epoch: 9, Step: 1419/5080
# Eval--Epoch: 9, Step: 1420/5080
# Eval--Epoch: 9, Step: 1421/5080
# Eval--Epoch: 9, Step: 1422/5080
# Eval--Epoch: 9, Step: 1423/5080
# Eval--Epoch: 9, Step: 1424/5080
# Eval--Epoch: 9, Step: 1425/5080
# Eval--Epoch: 9, Step: 1426/5080
# Eval--Epoch: 9, Step: 1427/5080
# Eval--Epoch: 9, Step: 1428/5080
# Eval--Epoch: 9, Step: 1429/5080
# Eval--Epoch: 9, Step: 1430/5080
# Eval--Epoch: 9, Step: 1431/5080
# Eval--Epoch: 9, Step: 1432/5080
# Eval--Epoch: 9, Step: 1433/5080
# Eval--Epoch: 9, Step: 1434/5080
# Eval--Epoch: 9, Step: 1435/5080
# Eval--Epoch: 9, Step: 1436/5080
# Eval--Epoch: 9, Step: 1437/5080
# Eval--Epoch: 9, Step: 1438/5080
# Eval--Epoch: 9, Step: 1439/5080
# Eval--Epoch: 9, Step: 1440/5080
# Eval--Epoch: 9, Step: 1441/5080
# Eval--Epoch: 9, Step: 1442/5080
# Eval--Epoch: 9, Step: 1443/5080
# Eval--Epoch: 9, Step: 1444/5080
# Eval--Epoch: 9, Step: 1445/5080
# Eval--Epoch: 9, Step: 1446/5080
# Eval--Epoch: 9, Step: 1447/5080
# Eval--Epoch: 9, Step: 1448/5080
# Eval--Epoch: 9, Step: 1449/5080
# Eval--Epoch: 9, Step: 1450/5080
# Eval--Epoch: 9, Step: 1451/5080
# Eval--Epoch: 9, Step: 1452/5080
# Eval--Epoch: 9, Step: 1453/5080
# Eval--Epoch: 9, Step: 1454/5080
# Eval--Epoch: 9, Step: 1455/5080
# Eval--Epoch: 9, Step: 1456/5080
# Eval--Epoch: 9, Step: 1457/5080
# Eval--Epoch: 9, Step: 1458/5080
# Eval--Epoch: 9, Step: 1459/5080
# Eval--Epoch: 9, Step: 1460/5080
# Eval--Epoch: 9, Step: 1461/5080
# Eval--Epoch: 9, Step: 1462/5080
# Eval--Epoch: 9, Step: 1463/5080
# Eval--Epoch: 9, Step: 1464/5080
# Eval--Epoch: 9, Step: 1465/5080
# Eval--Epoch: 9, Step: 1466/5080
# Eval--Epoch: 9, Step: 1467/5080
# Eval--Epoch: 9, Step: 1468/5080
# Eval--Epoch: 9, Step: 1469/5080
# Eval--Epoch: 9, Step: 1470/5080
# Eval--Epoch: 9, Step: 1471/5080
# Eval--Epoch: 9, Step: 1472/5080
# Eval--Epoch: 9, Step: 1473/5080
# Eval--Epoch: 9, Step: 1474/5080
# Eval--Epoch: 9, Step: 1475/5080
# Eval--Epoch: 9, Step: 1476/5080
# Eval--Epoch: 9, Step: 1477/5080
# Eval--Epoch: 9, Step: 1478/5080
# Eval--Epoch: 9, Step: 1479/5080
# Eval--Epoch: 9, Step: 1480/5080
# Eval--Epoch: 9, Step: 1481/5080
# Eval--Epoch: 9, Step: 1482/5080
# Eval--Epoch: 9, Step: 1483/5080
# Eval--Epoch: 9, Step: 1484/5080
# Eval--Epoch: 9, Step: 1485/5080
# Eval--Epoch: 9, Step: 1486/5080
# Eval--Epoch: 9, Step: 1487/5080
# Eval--Epoch: 9, Step: 1488/5080
# Eval--Epoch: 9, Step: 1489/5080
# Eval--Epoch: 9, Step: 1490/5080
# Eval--Epoch: 9, Step: 1491/5080
# Eval--Epoch: 9, Step: 1492/5080
# Eval--Epoch: 9, Step: 1493/5080
# Eval--Epoch: 9, Step: 1494/5080
# Eval--Epoch: 9, Step: 1495/5080
# Eval--Epoch: 9, Step: 1496/5080
# Eval--Epoch: 9, Step: 1497/5080
# Eval--Epoch: 9, Step: 1498/5080
# Eval--Epoch: 9, Step: 1499/5080
# Eval--Epoch: 9, Step: 1500/5080
# Eval--Epoch: 9, Step: 1501/5080
# Eval--Epoch: 9, Step: 1502/5080
# Eval--Epoch: 9, Step: 1503/5080
# Eval--Epoch: 9, Step: 1504/5080
# Eval--Epoch: 9, Step: 1505/5080
# Eval--Epoch: 9, Step: 1506/5080
# Eval--Epoch: 9, Step: 1507/5080
# Eval--Epoch: 9, Step: 1508/5080
# Eval--Epoch: 9, Step: 1509/5080
# Eval--Epoch: 9, Step: 1510/5080
# Eval--Epoch: 9, Step: 1511/5080
# Eval--Epoch: 9, Step: 1512/5080
# Eval--Epoch: 9, Step: 1513/5080
# Eval--Epoch: 9, Step: 1514/5080
# Eval--Epoch: 9, Step: 1515/5080
# Eval--Epoch: 9, Step: 1516/5080
# Eval--Epoch: 9, Step: 1517/5080
# Eval--Epoch: 9, Step: 1518/5080
# Eval--Epoch: 9, Step: 1519/5080
# Eval--Epoch: 9, Step: 1520/5080
# Eval--Epoch: 9, Step: 1521/5080
# Eval--Epoch: 9, Step: 1522/5080
# Eval--Epoch: 9, Step: 1523/5080
# Eval--Epoch: 9, Step: 1524/5080
# Eval--Epoch: 9, Step: 1525/5080
# Eval--Epoch: 9, Step: 1526/5080
# Eval--Epoch: 9, Step: 1527/5080
# Eval--Epoch: 9, Step: 1528/5080
# Eval--Epoch: 9, Step: 1529/5080
# Eval--Epoch: 9, Step: 1530/5080
# Eval--Epoch: 9, Step: 1531/5080
# Eval--Epoch: 9, Step: 1532/5080
# Eval--Epoch: 9, Step: 1533/5080
# Eval--Epoch: 9, Step: 1534/5080
# Eval--Epoch: 9, Step: 1535/5080
# Eval--Epoch: 9, Step: 1536/5080
# Eval--Epoch: 9, Step: 1537/5080
# Eval--Epoch: 9, Step: 1538/5080
# Eval--Epoch: 9, Step: 1539/5080
# Eval--Epoch: 9, Step: 1540/5080
# Eval--Epoch: 9, Step: 1541/5080
# Eval--Epoch: 9, Step: 1542/5080
# Eval--Epoch: 9, Step: 1543/5080
# Eval--Epoch: 9, Step: 1544/5080
# Eval--Epoch: 9, Step: 1545/5080
# Eval--Epoch: 9, Step: 1546/5080
# Eval--Epoch: 9, Step: 1547/5080
# Eval--Epoch: 9, Step: 1548/5080
# Eval--Epoch: 9, Step: 1549/5080
# Eval--Epoch: 9, Step: 1550/5080
# Eval--Epoch: 9, Step: 1551/5080
# Eval--Epoch: 9, Step: 1552/5080
# Eval--Epoch: 9, Step: 1553/5080
# Eval--Epoch: 9, Step: 1554/5080
# Eval--Epoch: 9, Step: 1555/5080
# Eval--Epoch: 9, Step: 1556/5080
# Eval--Epoch: 9, Step: 1557/5080
# Eval--Epoch: 9, Step: 1558/5080
# Eval--Epoch: 9, Step: 1559/5080
# Eval--Epoch: 9, Step: 1560/5080
# Eval--Epoch: 9, Step: 1561/5080
# Eval--Epoch: 9, Step: 1562/5080
# Eval--Epoch: 9, Step: 1563/5080
# Eval--Epoch: 9, Step: 1564/5080
# Eval--Epoch: 9, Step: 1565/5080
# Eval--Epoch: 9, Step: 1566/5080
# Eval--Epoch: 9, Step: 1567/5080
# Eval--Epoch: 9, Step: 1568/5080
# Eval--Epoch: 9, Step: 1569/5080
# Eval--Epoch: 9, Step: 1570/5080
# Eval--Epoch: 9, Step: 1571/5080
# Eval--Epoch: 9, Step: 1572/5080
# Eval--Epoch: 9, Step: 1573/5080
# Eval--Epoch: 9, Step: 1574/5080
# Eval--Epoch: 9, Step: 1575/5080
# Eval--Epoch: 9, Step: 1576/5080
# Eval--Epoch: 9, Step: 1577/5080
# Eval--Epoch: 9, Step: 1578/5080
# Eval--Epoch: 9, Step: 1579/5080
# Eval--Epoch: 9, Step: 1580/5080
# Eval--Epoch: 9, Step: 1581/5080
# Eval--Epoch: 9, Step: 1582/5080
# Eval--Epoch: 9, Step: 1583/5080
# Eval--Epoch: 9, Step: 1584/5080
# Eval--Epoch: 9, Step: 1585/5080
# Eval--Epoch: 9, Step: 1586/5080
# Eval--Epoch: 9, Step: 1587/5080
# Eval--Epoch: 9, Step: 1588/5080
# Eval--Epoch: 9, Step: 1589/5080
# Eval--Epoch: 9, Step: 1590/5080
# Eval--Epoch: 9, Step: 1591/5080
# Eval--Epoch: 9, Step: 1592/5080
# Eval--Epoch: 9, Step: 1593/5080
# Eval--Epoch: 9, Step: 1594/5080
# Eval--Epoch: 9, Step: 1595/5080
# Eval--Epoch: 9, Step: 1596/5080
# Eval--Epoch: 9, Step: 1597/5080
# Eval--Epoch: 9, Step: 1598/5080
# Eval--Epoch: 9, Step: 1599/5080
# Eval--Epoch: 9, Step: 1600/5080
# Eval--Epoch: 9, Step: 1601/5080
# Eval--Epoch: 9, Step: 1602/5080
# Eval--Epoch: 9, Step: 1603/5080
# Eval--Epoch: 9, Step: 1604/5080
# Eval--Epoch: 9, Step: 1605/5080
# Eval--Epoch: 9, Step: 1606/5080
# Eval--Epoch: 9, Step: 1607/5080
# Eval--Epoch: 9, Step: 1608/5080
# Eval--Epoch: 9, Step: 1609/5080
# ...
# Eval--Epoch: 9, Step: 4589/5080
# Eval--Epoch: 9, Step: 4590/5080
# Eval--Epoch: 9, Step: 4591/5080
# Eval--Epoch: 9, Step: 4592/5080
# Eval--Epoch: 9, Step: 4593/5080
# Eval--Epoch: 9, Step: 4594/5080
# Eval--Epoch: 9, Step: 4595/5080
# Eval--Epoch: 9, Step: 4596/5080
# Eval--Epoch: 9, Step: 4597/5080
# Eval--Epoch: 9, Step: 4598/5080
# Eval--Epoch: 9, Step: 4599/5080
# Eval--Epoch: 9, Step: 4600/5080
# Eval--Epoch: 9, Step: 4601/5080
# Eval--Epoch: 9, Step: 4602/5080
# Eval--Epoch: 9, Step: 4603/5080
# Eval--Epoch: 9, Step: 4604/5080
# Eval--Epoch: 9, Step: 4605/5080
# Eval--Epoch: 9, Step: 4606/5080
# Eval--Epoch: 9, Step: 4607/5080
# Eval--Epoch: 9, Step: 4608/5080
# Eval--Epoch: 9, Step: 4609/5080
# Eval--Epoch: 9, Step: 4610/5080
# Eval--Epoch: 9, Step: 4611/5080
# Eval--Epoch: 9, Step: 4612/5080
# Eval--Epoch: 9, Step: 4613/5080
# Eval--Epoch: 9, Step: 4614/5080
# Eval--Epoch: 9, Step: 4615/5080
# Eval--Epoch: 9, Step: 4616/5080
# Eval--Epoch: 9, Step: 4617/5080
# Eval--Epoch: 9, Step: 4618/5080
# Eval--Epoch: 9, Step: 4619/5080
# Eval--Epoch: 9, Step: 4620/5080
# Eval--Epoch: 9, Step: 4621/5080
# Eval--Epoch: 9, Step: 4622/5080
# Eval--Epoch: 9, Step: 4623/5080
# Eval--Epoch: 9, Step: 4624/5080
# Eval--Epoch: 9, Step: 4625/5080
# Eval--Epoch: 9, Step: 4626/5080
# Eval--Epoch: 9, Step: 4627/5080
# Eval--Epoch: 9, Step: 4628/5080
# Eval--Epoch: 9, Step: 4629/5080
# Eval--Epoch: 9, Step: 4630/5080
# Eval--Epoch: 9, Step: 4631/5080
# Eval--Epoch: 9, Step: 4632/5080
# Eval--Epoch: 9, Step: 4633/5080
# Eval--Epoch: 9, Step: 4634/5080
# Eval--Epoch: 9, Step: 4635/5080
# Eval--Epoch: 9, Step: 4636/5080
# Eval--Epoch: 9, Step: 4637/5080
# Eval--Epoch: 9, Step: 4638/5080
# Eval--Epoch: 9, Step: 4639/5080
# Eval--Epoch: 9, Step: 4640/5080
# Eval--Epoch: 9, Step: 4641/5080
# Eval--Epoch: 9, Step: 4642/5080
# Eval--Epoch: 9, Step: 4643/5080
# Eval--Epoch: 9, Step: 4644/5080
# Eval--Epoch: 9, Step: 4645/5080
# Eval--Epoch: 9, Step: 4646/5080
# Eval--Epoch: 9, Step: 4647/5080
# Eval--Epoch: 9, Step: 4648/5080
# Eval--Epoch: 9, Step: 4649/5080
# Eval--Epoch: 9, Step: 4650/5080
# Eval--Epoch: 9, Step: 4651/5080
# Eval--Epoch: 9, Step: 4652/5080
# Eval--Epoch: 9, Step: 4653/5080
# Eval--Epoch: 9, Step: 4654/5080
# Eval--Epoch: 9, Step: 4655/5080
# Eval--Epoch: 9, Step: 4656/5080
# Eval--Epoch: 9, Step: 4657/5080
# Eval--Epoch: 9, Step: 4658/5080
# Eval--Epoch: 9, Step: 4659/5080
# Eval--Epoch: 9, Step: 4660/5080
# Eval--Epoch: 9, Step: 4661/5080
# Eval--Epoch: 9, Step: 4662/5080
# Eval--Epoch: 9, Step: 4663/5080
# Eval--Epoch: 9, Step: 4664/5080
# Eval--Epoch: 9, Step: 4665/5080
# Eval--Epoch: 9, Step: 4666/5080
# Eval--Epoch: 9, Step: 4667/5080
# Eval--Epoch: 9, Step: 4668/5080
# Eval--Epoch: 9, Step: 4669/5080
# Eval--Epoch: 9, Step: 4670/5080
# Eval--Epoch: 9, Step: 4671/5080
# Eval--Epoch: 9, Step: 4672/5080
# Eval--Epoch: 9, Step: 4673/5080
# Eval--Epoch: 9, Step: 4674/5080
# Eval--Epoch: 9, Step: 4675/5080
# Eval--Epoch: 9, Step: 4676/5080
# Eval--Epoch: 9, Step: 4677/5080
# Eval--Epoch: 9, Step: 4678/5080
# Eval--Epoch: 9, Step: 4679/5080
# Eval--Epoch: 9, Step: 4680/5080
# Eval--Epoch: 9, Step: 4681/5080
# Eval--Epoch: 9, Step: 4682/5080
# Eval--Epoch: 9, Step: 4683/5080
# Eval--Epoch: 9, Step: 4684/5080
# Eval--Epoch: 9, Step: 4685/5080
# Eval--Epoch: 9, Step: 4686/5080
# Eval--Epoch: 9, Step: 4687/5080
# Eval--Epoch: 9, Step: 4688/5080
# Eval--Epoch: 9, Step: 4689/5080
# Eval--Epoch: 9, Step: 4690/5080
# Eval--Epoch: 9, Step: 4691/5080
# Eval--Epoch: 9, Step: 4692/5080
# Eval--Epoch: 9, Step: 4693/5080
# Eval--Epoch: 9, Step: 4694/5080
# Eval--Epoch: 9, Step: 4695/5080
# Eval--Epoch: 9, Step: 4696/5080
# Eval--Epoch: 9, Step: 4697/5080
# Eval--Epoch: 9, Step: 4698/5080
# Eval--Epoch: 9, Step: 4699/5080
# Eval--Epoch: 9, Step: 4700/5080
# Eval--Epoch: 9, Step: 4701/5080
# Eval--Epoch: 9, Step: 4702/5080
# Eval--Epoch: 9, Step: 4703/5080
# Eval--Epoch: 9, Step: 4704/5080
# Eval--Epoch: 9, Step: 4705/5080
# Eval--Epoch: 9, Step: 4706/5080
# Eval--Epoch: 9, Step: 4707/5080
# Eval--Epoch: 9, Step: 4708/5080
# Eval--Epoch: 9, Step: 4709/5080
# Eval--Epoch: 9, Step: 4710/5080
# Eval--Epoch: 9, Step: 4711/5080
# Eval--Epoch: 9, Step: 4712/5080
# Eval--Epoch: 9, Step: 4713/5080
# Eval--Epoch: 9, Step: 4714/5080
# Eval--Epoch: 9, Step: 4715/5080
# Eval--Epoch: 9, Step: 4716/5080
# Eval--Epoch: 9, Step: 4717/5080
# Eval--Epoch: 9, Step: 4718/5080
# Eval--Epoch: 9, Step: 4719/5080
# Eval--Epoch: 9, Step: 4720/5080
# Eval--Epoch: 9, Step: 4721/5080
# Eval--Epoch: 9, Step: 4722/5080
# Eval--Epoch: 9, Step: 4723/5080
# Eval--Epoch: 9, Step: 4724/5080
# Eval--Epoch: 9, Step: 4725/5080
# Eval--Epoch: 9, Step: 4726/5080
# Eval--Epoch: 9, Step: 4727/5080
# Eval--Epoch: 9, Step: 4728/5080
# Eval--Epoch: 9, Step: 4729/5080
# Eval--Epoch: 9, Step: 4730/5080
# Eval--Epoch: 9, Step: 4731/5080
# Eval--Epoch: 9, Step: 4732/5080
# Eval--Epoch: 9, Step: 4733/5080
# Eval--Epoch: 9, Step: 4734/5080
# Eval--Epoch: 9, Step: 4735/5080
# Eval--Epoch: 9, Step: 4736/5080
# Eval--Epoch: 9, Step: 4737/5080
# Eval--Epoch: 9, Step: 4738/5080
# Eval--Epoch: 9, Step: 4739/5080
# Eval--Epoch: 9, Step: 4740/5080
# Eval--Epoch: 9, Step: 4741/5080
# Eval--Epoch: 9, Step: 4742/5080
# Eval--Epoch: 9, Step: 4743/5080
# Eval--Epoch: 9, Step: 4744/5080
# Eval--Epoch: 9, Step: 4745/5080
# Eval--Epoch: 9, Step: 4746/5080
# Eval--Epoch: 9, Step: 4747/5080
# Eval--Epoch: 9, Step: 4748/5080
# Eval--Epoch: 9, Step: 4749/5080
# Eval--Epoch: 9, Step: 4750/5080
# Eval--Epoch: 9, Step: 4751/5080
# Eval--Epoch: 9, Step: 4752/5080
# Eval--Epoch: 9, Step: 4753/5080
# Eval--Epoch: 9, Step: 4754/5080
# Eval--Epoch: 9, Step: 4755/5080
# Eval--Epoch: 9, Step: 4756/5080
# Eval--Epoch: 9, Step: 4757/5080
# Eval--Epoch: 9, Step: 4758/5080
# Eval--Epoch: 9, Step: 4759/5080
# Eval--Epoch: 9, Step: 4760/5080
# Eval--Epoch: 9, Step: 4761/5080
# Eval--Epoch: 9, Step: 4762/5080
# Eval--Epoch: 9, Step: 4763/5080
# Eval--Epoch: 9, Step: 4764/5080
# Eval--Epoch: 9, Step: 4765/5080
# Eval--Epoch: 9, Step: 4766/5080
# Eval--Epoch: 9, Step: 4767/5080
# Eval--Epoch: 9, Step: 4768/5080
# Eval--Epoch: 9, Step: 4769/5080
# Eval--Epoch: 9, Step: 4770/5080
# Eval--Epoch: 9, Step: 4771/5080
# Eval--Epoch: 9, Step: 4772/5080
# Eval--Epoch: 9, Step: 4773/5080
# Eval--Epoch: 9, Step: 4774/5080
# Eval--Epoch: 9, Step: 4775/5080
# Eval--Epoch: 9, Step: 4776/5080
# Eval--Epoch: 9, Step: 4777/5080
# Eval--Epoch: 9, Step: 4778/5080
# Eval--Epoch: 9, Step: 4779/5080
# Eval--Epoch: 9, Step: 4780/5080
# Eval--Epoch: 9, Step: 4781/5080
# Eval--Epoch: 9, Step: 4782/5080
# Eval--Epoch: 9, Step: 4783/5080
# Eval--Epoch: 9, Step: 4784/5080
# Eval--Epoch: 9, Step: 4785/5080
# Eval--Epoch: 9, Step: 4786/5080
# Eval--Epoch: 9, Step: 4787/5080
# Eval--Epoch: 9, Step: 4788/5080
# Eval--Epoch: 9, Step: 4789/5080
# Eval--Epoch: 9, Step: 4790/5080
# Eval--Epoch: 9, Step: 4791/5080
# Eval--Epoch: 9, Step: 4792/5080
# Eval--Epoch: 9, Step: 4793/5080
# Eval--Epoch: 9, Step: 4794/5080
# Eval--Epoch: 9, Step: 4795/5080
# Eval--Epoch: 9, Step: 4796/5080
# Eval--Epoch: 9, Step: 4797/5080
# Eval--Epoch: 9, Step: 4798/5080
# Eval--Epoch: 9, Step: 4799/5080
# Eval--Epoch: 9, Step: 4800/5080
# Eval--Epoch: 9, Step: 4801/5080
# Eval--Epoch: 9, Step: 4802/5080
# Eval--Epoch: 9, Step: 4803/5080
# Eval--Epoch: 9, Step: 4804/5080
# Eval--Epoch: 9, Step: 4805/5080
# Eval--Epoch: 9, Step: 4806/5080
# Eval--Epoch: 9, Step: 4807/5080
# Eval--Epoch: 9, Step: 4808/5080
# Eval--Epoch: 9, Step: 4809/5080
# Eval--Epoch: 9, Step: 4810/5080
# Eval--Epoch: 9, Step: 4811/5080
# Eval--Epoch: 9, Step: 4812/5080
# Eval--Epoch: 9, Step: 4813/5080
# Eval--Epoch: 9, Step: 4814/5080
# Eval--Epoch: 9, Step: 4815/5080
# Eval--Epoch: 9, Step: 4816/5080
# Eval--Epoch: 9, Step: 4817/5080
# Eval--Epoch: 9, Step: 4818/5080
# Eval--Epoch: 9, Step: 4819/5080
# Eval--Epoch: 9, Step: 4820/5080
# Eval--Epoch: 9, Step: 4821/5080
# Eval--Epoch: 9, Step: 4822/5080
# Eval--Epoch: 9, Step: 4823/5080
# Eval--Epoch: 9, Step: 4824/5080
# Eval--Epoch: 9, Step: 4825/5080
# Eval--Epoch: 9, Step: 4826/5080
# Eval--Epoch: 9, Step: 4827/5080
# Eval--Epoch: 9, Step: 4828/5080
# Eval--Epoch: 9, Step: 4829/5080
# Eval--Epoch: 9, Step: 4830/5080
# Eval--Epoch: 9, Step: 4831/5080
# Eval--Epoch: 9, Step: 4832/5080
# Eval--Epoch: 9, Step: 4833/5080
# Eval--Epoch: 9, Step: 4834/5080
# Eval--Epoch: 9, Step: 4835/5080
# Eval--Epoch: 9, Step: 4836/5080
# Eval--Epoch: 9, Step: 4837/5080
# Eval--Epoch: 9, Step: 4838/5080
# Eval--Epoch: 9, Step: 4839/5080
# Eval--Epoch: 9, Step: 4840/5080
# Eval--Epoch: 9, Step: 4841/5080
# Eval--Epoch: 9, Step: 4842/5080
# Eval--Epoch: 9, Step: 4843/5080
# Eval--Epoch: 9, Step: 4844/5080
# Eval--Epoch: 9, Step: 4845/5080
# Eval--Epoch: 9, Step: 4846/5080
# Eval--Epoch: 9, Step: 4847/5080
# Eval--Epoch: 9, Step: 4848/5080
# Eval--Epoch: 9, Step: 4849/5080
# Eval--Epoch: 9, Step: 4850/5080
# Eval--Epoch: 9, Step: 4851/5080
# Eval--Epoch: 9, Step: 4852/5080
# Eval--Epoch: 9, Step: 4853/5080
# Eval--Epoch: 9, Step: 4854/5080
# Eval--Epoch: 9, Step: 4855/5080
# Eval--Epoch: 9, Step: 4856/5080
# Eval--Epoch: 9, Step: 4857/5080
# Eval--Epoch: 9, Step: 4858/5080
# Eval--Epoch: 9, Step: 4859/5080
# Eval--Epoch: 9, Step: 4860/5080
# Eval--Epoch: 9, Step: 4861/5080
# Eval--Epoch: 9, Step: 4862/5080
# Eval--Epoch: 9, Step: 4863/5080
# Eval--Epoch: 9, Step: 4864/5080
# Eval--Epoch: 9, Step: 4865/5080
# Eval--Epoch: 9, Step: 4866/5080
# Eval--Epoch: 9, Step: 4867/5080
# Eval--Epoch: 9, Step: 4868/5080
# Eval--Epoch: 9, Step: 4869/5080
# Eval--Epoch: 9, Step: 4870/5080
# Eval--Epoch: 9, Step: 4871/5080
# Eval--Epoch: 9, Step: 4872/5080
# Eval--Epoch: 9, Step: 4873/5080
# Eval--Epoch: 9, Step: 4874/5080
# Eval--Epoch: 9, Step: 4875/5080
# Eval--Epoch: 9, Step: 4876/5080
# Eval--Epoch: 9, Step: 4877/5080
# Eval--Epoch: 9, Step: 4878/5080
# Eval--Epoch: 9, Step: 4879/5080
# Eval--Epoch: 9, Step: 4880/5080
# Eval--Epoch: 9, Step: 4881/5080
# Eval--Epoch: 9, Step: 4882/5080
# Eval--Epoch: 9, Step: 4883/5080
# Eval--Epoch: 9, Step: 4884/5080
# Eval--Epoch: 9, Step: 4885/5080
# Eval--Epoch: 9, Step: 4886/5080
# Eval--Epoch: 9, Step: 4887/5080
# Eval--Epoch: 9, Step: 4888/5080
# Eval--Epoch: 9, Step: 4889/5080
# Eval--Epoch: 9, Step: 4890/5080
# Eval--Epoch: 9, Step: 4891/5080
# Eval--Epoch: 9, Step: 4892/5080
# Eval--Epoch: 9, Step: 4893/5080
# Eval--Epoch: 9, Step: 4894/5080
# Eval--Epoch: 9, Step: 4895/5080
# Eval--Epoch: 9, Step: 4896/5080
# Eval--Epoch: 9, Step: 4897/5080
# Eval--Epoch: 9, Step: 4898/5080
# Eval--Epoch: 9, Step: 4899/5080
# Eval--Epoch: 9, Step: 4900/5080
# Eval--Epoch: 9, Step: 4901/5080
# Eval--Epoch: 9, Step: 4902/5080
# Eval--Epoch: 9, Step: 4903/5080
# Eval--Epoch: 9, Step: 4904/5080
# Eval--Epoch: 9, Step: 4905/5080
# Eval--Epoch: 9, Step: 4906/5080
# Eval--Epoch: 9, Step: 4907/5080
# Eval--Epoch: 9, Step: 4908/5080
# Eval--Epoch: 9, Step: 4909/5080
# Eval--Epoch: 9, Step: 4910/5080
# Eval--Epoch: 9, Step: 4911/5080
# Eval--Epoch: 9, Step: 4912/5080
# Eval--Epoch: 9, Step: 4913/5080
# Eval--Epoch: 9, Step: 4914/5080
# Eval--Epoch: 9, Step: 4915/5080
# Eval--Epoch: 9, Step: 4916/5080
# Eval--Epoch: 9, Step: 4917/5080
# Eval--Epoch: 9, Step: 4918/5080
# Eval--Epoch: 9, Step: 4919/5080
# Eval--Epoch: 9, Step: 4920/5080
# Eval--Epoch: 9, Step: 4921/5080
# Eval--Epoch: 9, Step: 4922/5080
# Eval--Epoch: 9, Step: 4923/5080
# Eval--Epoch: 9, Step: 4924/5080
# Eval--Epoch: 9, Step: 4925/5080
# Eval--Epoch: 9, Step: 4926/5080
# Eval--Epoch: 9, Step: 4927/5080
# Eval--Epoch: 9, Step: 4928/5080
# Eval--Epoch: 9, Step: 4929/5080
# Eval--Epoch: 9, Step: 4930/5080
# Eval--Epoch: 9, Step: 4931/5080
# Eval--Epoch: 9, Step: 4932/5080
# Eval--Epoch: 9, Step: 4933/5080
# Eval--Epoch: 9, Step: 4934/5080
# Eval--Epoch: 9, Step: 4935/5080
# Eval--Epoch: 9, Step: 4936/5080
# Eval--Epoch: 9, Step: 4937/5080
# Eval--Epoch: 9, Step: 4938/5080
# Eval--Epoch: 9, Step: 4939/5080
# Eval--Epoch: 9, Step: 4940/5080
# Eval--Epoch: 9, Step: 4941/5080
# Eval--Epoch: 9, Step: 4942/5080
# Eval--Epoch: 9, Step: 4943/5080
# Eval--Epoch: 9, Step: 4944/5080
# Eval--Epoch: 9, Step: 4945/5080
# Eval--Epoch: 9, Step: 4946/5080
# Eval--Epoch: 9, Step: 4947/5080
# Eval--Epoch: 9, Step: 4948/5080
# Eval--Epoch: 9, Step: 4949/5080
# Eval--Epoch: 9, Step: 4950/5080
# Eval--Epoch: 9, Step: 4951/5080
# Eval--Epoch: 9, Step: 4952/5080
# Eval--Epoch: 9, Step: 4953/5080
# Eval--Epoch: 9, Step: 4954/5080
# Eval--Epoch: 9, Step: 4955/5080
# Eval--Epoch: 9, Step: 4956/5080
# Eval--Epoch: 9, Step: 4957/5080
# Eval--Epoch: 9, Step: 4958/5080
# Eval--Epoch: 9, Step: 4959/5080
# Eval--Epoch: 9, Step: 4960/5080
# Eval--Epoch: 9, Step: 4961/5080
# Eval--Epoch: 9, Step: 4962/5080
# Eval--Epoch: 9, Step: 4963/5080
# Eval--Epoch: 9, Step: 4964/5080
# Eval--Epoch: 9, Step: 4965/5080
# Eval--Epoch: 9, Step: 4966/5080
# Eval--Epoch: 9, Step: 4967/5080
# Eval--Epoch: 9, Step: 4968/5080
# Eval--Epoch: 9, Step: 4969/5080
# Eval--Epoch: 9, Step: 4970/5080
# Eval--Epoch: 9, Step: 4971/5080
# Eval--Epoch: 9, Step: 4972/5080
# Eval--Epoch: 9, Step: 4973/5080
# Eval--Epoch: 9, Step: 4974/5080
# Eval--Epoch: 9, Step: 4975/5080
# Eval--Epoch: 9, Step: 4976/5080
# Eval--Epoch: 9, Step: 4977/5080
# Eval--Epoch: 9, Step: 4978/5080
# Eval--Epoch: 9, Step: 4979/5080
# Eval--Epoch: 9, Step: 4980/5080
# Eval--Epoch: 9, Step: 4981/5080
# Eval--Epoch: 9, Step: 4982/5080
# Eval--Epoch: 9, Step: 4983/5080
# Eval--Epoch: 9, Step: 4984/5080
# Eval--Epoch: 9, Step: 4985/5080
# Eval--Epoch: 9, Step: 4986/5080
# Eval--Epoch: 9, Step: 4987/5080
# Eval--Epoch: 9, Step: 4988/5080
# Eval--Epoch: 9, Step: 4989/5080
# Eval--Epoch: 9, Step: 4990/5080
# Eval--Epoch: 9, Step: 4991/5080
# Eval--Epoch: 9, Step: 4992/5080
# Eval--Epoch: 9, Step: 4993/5080
# Eval--Epoch: 9, Step: 4994/5080
# Eval--Epoch: 9, Step: 4995/5080
# Eval--Epoch: 9, Step: 4996/5080
# Eval--Epoch: 9, Step: 4997/5080
# Eval--Epoch: 9, Step: 4998/5080
# Eval--Epoch: 9, Step: 4999/5080
# Eval--Epoch: 9, Step: 5000/5080
# Eval--Epoch: 9, Step: 5001/5080
# Eval--Epoch: 9, Step: 5002/5080
# Eval--Epoch: 9, Step: 5003/5080
# Eval--Epoch: 9, Step: 5004/5080
# Eval--Epoch: 9, Step: 5005/5080
# Eval--Epoch: 9, Step: 5006/5080
# Eval--Epoch: 9, Step: 5007/5080
# Eval--Epoch: 9, Step: 5008/5080
# Eval--Epoch: 9, Step: 5009/5080
# Eval--Epoch: 9, Step: 5010/5080
# Eval--Epoch: 9, Step: 5011/5080
# Eval--Epoch: 9, Step: 5012/5080
# Eval--Epoch: 9, Step: 5013/5080
# Eval--Epoch: 9, Step: 5014/5080
# Eval--Epoch: 9, Step: 5015/5080
# Eval--Epoch: 9, Step: 5016/5080
# Eval--Epoch: 9, Step: 5017/5080
# Eval--Epoch: 9, Step: 5018/5080
# Eval--Epoch: 9, Step: 5019/5080
# Eval--Epoch: 9, Step: 5020/5080
# Eval--Epoch: 9, Step: 5021/5080
# Eval--Epoch: 9, Step: 5022/5080
# Eval--Epoch: 9, Step: 5023/5080
# Eval--Epoch: 9, Step: 5024/5080
# Eval--Epoch: 9, Step: 5025/5080
# Eval--Epoch: 9, Step: 5026/5080
# Eval--Epoch: 9, Step: 5027/5080
# Eval--Epoch: 9, Step: 5028/5080
# Eval--Epoch: 9, Step: 5029/5080
# Eval--Epoch: 9, Step: 5030/5080
# Eval--Epoch: 9, Step: 5031/5080
# Eval--Epoch: 9, Step: 5032/5080
# Eval--Epoch: 9, Step: 5033/5080
# Eval--Epoch: 9, Step: 5034/5080
# Eval--Epoch: 9, Step: 5035/5080
# Eval--Epoch: 9, Step: 5036/5080
# Eval--Epoch: 9, Step: 5037/5080
# Eval--Epoch: 9, Step: 5038/5080
# Eval--Epoch: 9, Step: 5039/5080
# Eval--Epoch: 9, Step: 5040/5080
# Eval--Epoch: 9, Step: 5041/5080
# Eval--Epoch: 9, Step: 5042/5080
# Eval--Epoch: 9, Step: 5043/5080
# Eval--Epoch: 9, Step: 5044/5080
# Eval--Epoch: 9, Step: 5045/5080
# Eval--Epoch: 9, Step: 5046/5080
# Eval--Epoch: 9, Step: 5047/5080
# Eval--Epoch: 9, Step: 5048/5080
# Eval--Epoch: 9, Step: 5049/5080
# Eval--Epoch: 9, Step: 5050/5080
# Eval--Epoch: 9, Step: 5051/5080
# Eval--Epoch: 9, Step: 5052/5080
# Eval--Epoch: 9, Step: 5053/5080
# Eval--Epoch: 9, Step: 5054/5080
# Eval--Epoch: 9, Step: 5055/5080
# Eval--Epoch: 9, Step: 5056/5080
# Eval--Epoch: 9, Step: 5057/5080
# Eval--Epoch: 9, Step: 5058/5080
# Eval--Epoch: 9, Step: 5059/5080
# Eval--Epoch: 9, Step: 5060/5080
# Eval--Epoch: 9, Step: 5061/5080
# Eval--Epoch: 9, Step: 5062/5080
# Eval--Epoch: 9, Step: 5063/5080
# Eval--Epoch: 9, Step: 5064/5080
# Eval--Epoch: 9, Step: 5065/5080
# Eval--Epoch: 9, Step: 5066/5080
# Eval--Epoch: 9, Step: 5067/5080
# Eval--Epoch: 9, Step: 5068/5080
# Eval--Epoch: 9, Step: 5069/5080
# Eval--Epoch: 9, Step: 5070/5080
# Eval--Epoch: 9, Step: 5071/5080
# Eval--Epoch: 9, Step: 5072/5080
# Eval--Epoch: 9, Step: 5073/5080
# Eval--Epoch: 9, Step: 5074/5080
# Eval--Epoch: 9, Step: 5075/5080
# Eval--Epoch: 9, Step: 5076/5080
# Eval--Epoch: 9, Step: 5077/5080
# Eval--Epoch: 9, Step: 5078/5080
# Eval--Epoch: 9, Step: 5079/5080
# 	DDI Rate: 0.0589, Jaccard: 0.4395,  PRAUC: 0.6826, AVG_PRC: 0.6246, AVG_RECALL: 0.6055, AVG_F1: 0.5964
#
# 0.08662137309029418 0.9172413793103448 0.0656242455379333 0.058920375770904046 0.439476217552379 0.6826096670177206 0.6245842606240574 0.6054967229295651 0.596381171208529

# %% [markdown]
# ### Results for 10  epochs

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Discussion
#
# The GAMENet paper was reproducible, and we have shown the work above, however, the loss function that we have employed confirmst the trainablity of the Model, and we are converging. The paper has actually used a  combined loss function, which penalizes the model for increasing ddi. This will be included in the next phase.
#
# The code that came with the paper was well modularized, and defined, and made it easy to reproduce.
#
# The Model definition, and the design was also a bit confusing. The NeuralNetwork that became the GAMENET augmented Seq2Seq model is implemented in one network, which makes the Network a bit complex.
#
# In the next phase, we will:
#
#
# *   Update our loss function.
# *   Modularize the Neural Network, to facilitate easier implementation.
# *   Perform some model comparisons.

# %% [markdown]
# # Model Comparison

# %% [markdown]
# ## Logistic Regression

# %% [markdown]
# ### Data prep

# %% [markdown]
# Creating dataset :
# For Linear Regression , the feature dictionary created for GAMENET was reused and the features were taken from a “medical code : numerical value” mapping to a muti hot encoding form .
#
# Example: \
#
#
# > **Input**  : \
# Total drugs : 5 \
# DRUG_3 : 3, \
# DRUG_4 : 4 \
# DRUG_5 : 5 \
# drugs_vector_for_visit_X = [3 ,4 ,5]
#
#
#
#
#
# > **Output** : \
# multi_hot_encoding_output : [0 , 0 , 1, 1,1]

# %%
from  baseline.train_LR import main, main2

ddi_rate, ja, prauc, avg_p, avg_r, avg_f1 = main()
# Out:
# running training
# 	DDI Rate: 0.0782, Jaccard: 0.4087, PRAUC: 0.6739, AVG_PRC: 0.6730, AVG_RECALL: 0.5224, AVG_F1: 0.5669
#
# avg med 11.370468611847922

# %%
curves = [
    ([ja,ja],'valid_ja','None','jaccard score','valid jaccard score'),
    ([prauc,prauc],'valid_prauc','None','prauc','valid prauc'),
    ([avg_p,avg_p],'valid p','None','p','valid p'),
    ([avg_r,avg_r],'valid r','None','r','valid r'),
    ([avg_f1,avg_f1],'valid f1','None','f1','valid f1')
]

plot_learning_curves_2(curves)
# Out:
# valid_ja valid jaccard score
# 2
# valid_prauc valid prauc
# 2
# valid p valid p
# 2
# valid r valid r
# 2
# valid f1 valid f1
# 2

# %% [markdown]
# ## Leap

# %%
from keras.preprocessing.sequence import pad_sequences

import torch
import torch.nn as nn
from sklearn.metrics import jaccard_score, roc_auc_score, precision_score, f1_score, average_precision_score
import numpy as np
import dill
import time
from torch.nn import CrossEntropyLoss
from torch.optim import Adam
import os
import torch.nn.functional as F
import random
from collections import defaultdict

import sys
sys.path.append('code')
sys.path.append("..")
from models import Leap
from util import llprint, sequence_metric, sequence_output_process, ddi_rate_score, get_n_params

torch.manual_seed(1203)

model_name = 'Leap'
resume_name = ''


def eval(model, data_eval, voc_size, epoch):
    print('')
    model.eval()

    ja, prauc, avg_p, avg_r, avg_f1 = [[] for _ in range(5)]
    records = []
    med_cnt = 0
    visit_cnt = 0
    for step, input in enumerate(data_eval):
        y_gt = []
        y_pred = []
        y_pred_prob = []
        y_pred_label = []
        for adm in input:
            y_gt_tmp = np.zeros(voc_size[2])
            y_gt_tmp[adm[2]] = 1
            y_gt.append(y_gt_tmp)

            output_logits = model(adm)
            output_logits = output_logits.detach().cpu().numpy()

            out_list, sorted_predict = sequence_output_process(output_logits, [voc_size[2], voc_size[2]+1])

            y_pred_label.append(sorted(sorted_predict))
            y_pred_prob.append(np.mean(output_logits[:, :-2], axis=0))

            y_pred_tmp = np.zeros(voc_size[2])
            y_pred_tmp[out_list] = 1
            y_pred.append(y_pred_tmp)
            visit_cnt += 1
            med_cnt += len(sorted_predict)

        records.append(y_pred_label)

        y_gt_array = np.array(y_gt)
        y_pred_array = np.array(y_pred)
        y_pred_prob_array = np.array(y_pred_prob)
        # Padding y_pred_label to ensure all are the same length
        y_pred_label_padded = pad_sequences(y_pred_label, padding='post', value=-1)
        y_pred_label_array = np.array(y_pred_label_padded, dtype=object)
        adm_ja, adm_prauc, adm_avg_p, adm_avg_r, adm_avg_f1 = sequence_metric(y_gt_array, y_pred_array, y_pred_prob_array, y_pred_label_array)
        ja.append(adm_ja)
        prauc.append(adm_prauc)
        avg_p.append(adm_avg_p)
        avg_r.append(adm_avg_r)
        avg_f1.append(adm_avg_f1)
        llprint('\rEval--Epoch: %d, Step: %d/%d' % (epoch, step, len(data_eval)))

# ddi rate
    ddi_rate = ddi_rate_score(records)
    llprint('\tDDI Rate: %.4f, Jaccard: %.4f,  PRAUC: %.4f, AVG_PRC: %.4f, AVG_RECALL: %.4f, AVG_F1: %.4f\n' % (
        ddi_rate, np.mean(ja), np.mean(prauc), np.mean(avg_p), np.mean(avg_r), np.mean(avg_f1)
    ))
    print('avg med', med_cnt / visit_cnt)
    return ddi_rate, np.mean(ja), np.mean(prauc), np.mean(avg_p), np.mean(avg_r), np.mean(avg_f1)


def oldeval(model, data_eval, voc_size, epoch):
    # evaluate
    print('')
    model.eval()

    ja, prauc, avg_p, avg_r, avg_f1 = [[] for _ in range(5)]
    records = []
    med_cnt = 0
    visit_cnt = 0
    for step, input in enumerate(data_eval):
        y_gt = []
        y_pred = []
        y_pred_prob = []
        y_pred_label = []
        for adm in input:
            y_gt_tmp = np.zeros(voc_size[2])
            y_gt_tmp[adm[2]] = 1
            y_gt.append(y_gt_tmp)

            output_logits = model(adm)
            output_logits = output_logits.detach().cpu().numpy()

            out_list, sorted_predict = sequence_output_process(output_logits, [voc_size[2], voc_size[2]+1])

            y_pred_label.append(sorted(sorted_predict))
            y_pred_prob.append(np.mean(output_logits[:, :-2], axis=0))

            y_pred_tmp = np.zeros(voc_size[2])
            y_pred_tmp[out_list] = 1
            y_pred.append(y_pred_tmp)
            visit_cnt += 1
            med_cnt += len(sorted_predict)

        records.append(y_pred_label)


        y_gt_array = np.array(y_gt)
        y_pred_array = np.array(y_pred)
        y_pred_prob_array = np.array(y_pred_prob)
        y_pred_label_array = np.array(y_pred_label)
        adm_ja, adm_prauc, adm_avg_p, adm_avg_r, adm_avg_f1 = sequence_metric(y_gt_array, y_pred_array, y_pred_prob_array, y_pred_label_array)
        ja.append(adm_ja)
        prauc.append(adm_prauc)
        avg_p.append(adm_avg_p)
        avg_r.append(adm_avg_r)
        avg_f1.append(adm_avg_f1)
        llprint('\rEval--Epoch: %d, Step: %d/%d' % (epoch, step, len(data_eval)))

    # ddi rate
    ddi_rate = ddi_rate_score(records)
    llprint('\tDDI Rate: %.4f, Jaccard: %.4f,  PRAUC: %.4f, AVG_PRC: %.4f, AVG_RECALL: %.4f, AVG_F1: %.4f\n' % (
        ddi_rate, np.mean(ja), np.mean(prauc), np.mean(avg_p), np.mean(avg_r), np.mean(avg_f1)
    ))
    print('avg med', med_cnt / visit_cnt)
    return ddi_rate, np.mean(ja), np.mean(prauc), np.mean(avg_p), np.mean(avg_r), np.mean(avg_f1)

def main():
    if not os.path.exists(os.path.join("saved", model_name)):
        os.makedirs(os.path.join("saved", model_name))

    data_path = 'data/records_final.pkl'
    voc_path = 'data/voc_final.pkl'
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print("Device available for running: ")
    print(device)

    data = dill.load(open(data_path, 'rb'))
    voc = dill.load(open(voc_path, 'rb'))
    diag_voc, pro_voc, med_voc = voc['diag_voc'], voc['pro_voc'], voc['med_voc']


    split_point = int(len(data) * 2 / 3)
    data_train = data[:split_point]
    eval_len = int(len(data[split_point:]) / 2)
    data_test = data[split_point:split_point + eval_len]
    data_eval = data[split_point+eval_len:]
    voc_size = (len(diag_voc.idx2word), len(pro_voc.idx2word), len(med_voc.idx2word))

    EPOCH = 1
    LR = 0.002
    TEST = False
    END_TOKEN = voc_size[2] + 1

    model = Leap(voc_size, device=device)
    if TEST:
        model.load_state_dict(torch.load(open(os.path.join("saved", model_name, resume_name), 'rb')))
        # pass

    model.to(device=device)
    print('parameters', get_n_params(model))

    optimizer = Adam(model.parameters(), lr=LR)

    if TEST:
        eval(model, data_test, voc_size, 0)
    else:
        history = defaultdict(list)
        for epoch in range(EPOCH):
            loss_record = []
            start_time = time.time()
            model.train()
            for step, input in enumerate(data_train):
                for adm in input:
                    loss_target = adm[2] + [END_TOKEN]
                    output_logits = model(adm)
                    loss = F.cross_entropy(output_logits, torch.LongTensor(loss_target).to(device))

                    loss_record.append(loss.item())

                    optimizer.zero_grad()
                    loss.backward(retain_graph=True)
                    optimizer.step()

                llprint('\rTrain--Epoch: %d, Step: %d/%d' % (epoch, step, len(data_train)))
            aa = eval(model, data_eval, voc_size, epoch)
            print(aa)
            ddi_rate, ja, prauc, avg_p, avg_r, avg_f1 = aa
            history['ja'].append(ja)
            history['ddi_rate'].append(ddi_rate)
            history['avg_p'].append(avg_p)
            history['avg_r'].append(avg_r)
            history['avg_f1'].append(avg_f1)
            history['prauc'].append(prauc)

            end_time = time.time()
            elapsed_time = (end_time - start_time) / 60
            llprint('\tEpoch: %d, Loss1: %.4f, One Epoch Time: %.2fm, Appro Left Time: %.2fh\n' % (epoch,
                                                                                                np.mean(loss_record),
                                                                                                elapsed_time,
                                                                                                elapsed_time * (
                                                                                                            EPOCH - epoch - 1)/60))

            # torch.save(model.state_dict(), open( os.path.join('saved', model_name, 'Epoch_%d_JA_%.4f_DDI_%.4f.model' % (epoch, ja, ddi_rate)), 'wb'))
            print('')

        # dill.dump(history, open(os.path.join('saved', model_name, 'history.pkl'), 'wb'))
        # test
        torch.save(model.state_dict(), open(
            os.path.join('saved', model_name, 'final.model'), 'wb'))

        return history


history = main()

curves = [
    (history['ddi_rate'],'valid_ddi_score','epoch','ddi_score','valid ddi score'),
    (history['ja'],'valid_ja','epoch','jaccard score','valid jaccard score'),
    (history['prauc'],'valid_prauc','epoch','prauc','valid prauc'),
    (history['avg_p'],'valid p','epoch','p','valid p'),
    (history['avg_r'],'valid r','epoch','r','valid r'),
    (history['avg_f1'],'valid f1','epoch','f1','valid f1')
]

plot_learning_curves_3(curves)
# Out:
# Device available for running:
# cuda
# parameters 436884
# Train--Epoch: 0, Step: 4232/4233
# Eval--Epoch: 0, Step: 1058/1059	DDI Rate: 0.0561, Jaccard: 0.3360,  PRAUC: 0.5148, AVG_PRC: 0.4778, AVG_RECALL: 0.5175, AVG_F1: 0.4784
# avg med 14.151382185168934
# (0.056132269099201826, 0.3359982722894921, 0.5148240843582319, 0.4778362311301297, 0.5174667263062055, 0.4784122111447246)
# 	Epoch: 0, Loss1: 3.0190, One Epoch Time: 5.07m, Appro Left Time: 0.76h
#
# Train--Epoch: 1, Step: 4232/4233
# Eval--Epoch: 1, Step: 1058/1059	DDI Rate: 0.0654, Jaccard: 0.3475,  PRAUC: 0.5123, AVG_PRC: 0.5036, AVG_RECALL: 0.5154, AVG_F1: 0.4882
# avg med 13.17200526546731
# (0.06541960124022093, 0.3474533347270103, 0.5123116558081338, 0.5036282592994655, 0.5154145784257642, 0.48815395278119217)
# 	Epoch: 1, Loss1: 2.8767, One Epoch Time: 5.08m, Appro Left Time: 0.68h
#
# Train--Epoch: 2, Step: 4232/4233
# Eval--Epoch: 2, Step: 1058/1059	DDI Rate: 0.0650, Jaccard: 0.3570,  PRAUC: 0.5157, AVG_PRC: 0.5064, AVG_RECALL: 0.5409, AVG_F1: 0.5042
# avg med 14.163668275559456
# (0.06500187483423722, 0.357028915413753, 0.515651536091154, 0.5063655501462082, 0.5408505331294622, 0.5041678783361915)
# 	Epoch: 2, Loss1: 2.8279, One Epoch Time: 5.03m, Appro Left Time: 0.59h
#
# Train--Epoch: 3, Step: 4232/4233
# Eval--Epoch: 3, Step: 1058/1059	DDI Rate: 0.0537, Jaccard: 0.3536,  PRAUC: 0.5008, AVG_PRC: 0.5053, AVG_RECALL: 0.5338, AVG_F1: 0.4991
# avg med 13.898200965335674
# (0.0536694450091482, 0.35363102832636395, 0.5007533358695984, 0.5053290251218271, 0.5338464371270691, 0.4991442897376436)
# 	Epoch: 3, Loss1: 2.8085, One Epoch Time: 5.01m, Appro Left Time: 0.50h
#
# Train--Epoch: 4, Step: 4232/4233
# Eval--Epoch: 4, Step: 1058/1059	DDI Rate: 0.0573, Jaccard: 0.3697,  PRAUC: 0.5083, AVG_PRC: 0.5248, AVG_RECALL: 0.5542, AVG_F1: 0.5201
# avg med 14.255375164545853
# (0.05729736573190693, 0.3696688702614087, 0.5082573589854937, 0.5248079553747487, 0.5541762131118262, 0.5201436926723247)
# 	Epoch: 4, Loss1: 2.7962, One Epoch Time: 5.02m, Appro Left Time: 0.42h
#
# Train--Epoch: 5, Step: 4232/4233
# Eval--Epoch: 5, Step: 1058/1059	DDI Rate: 0.0549, Jaccard: 0.3580,  PRAUC: 0.5086, AVG_PRC: 0.5060, AVG_RECALL: 0.5394, AVG_F1: 0.5008
# avg med 13.89293549802545
# (0.054885948542377, 0.35796302586938195, 0.5086227490604103, 0.505982235832301, 0.5394083788494058, 0.5008310897257199)
# 	Epoch: 5, Loss1: 2.7856, One Epoch Time: 5.04m, Appro Left Time: 0.34h
#
# Train--Epoch: 6, Step: 4232/4233
# Eval--Epoch: 6, Step: 1058/1059	DDI Rate: 0.0567, Jaccard: 0.3549,  PRAUC: 0.5149, AVG_PRC: 0.4900, AVG_RECALL: 0.5571, AVG_F1: 0.5019
# avg med 15.249670908293112
# (0.056707214617581894, 0.3548923457537247, 0.5148545221814256, 0.4900212334467723, 0.557050074909495, 0.5019449149711936)
# 	Epoch: 6, Loss1: 2.7873, One Epoch Time: 5.01m, Appro Left Time: 0.25h
#
# Train--Epoch: 7, Step: 4232/4233
# Eval--Epoch: 7, Step: 1058/1059	DDI Rate: 0.0528, Jaccard: 0.3551,  PRAUC: 0.5142, AVG_PRC: 0.4930, AVG_RECALL: 0.5489, AVG_F1: 0.5006
# avg med 14.776656428258008
# (0.05284942961337217, 0.35511439540598055, 0.514216387561988, 0.4929914251600098, 0.5488708685395338, 0.5006356403567661)
# 	Epoch: 7, Loss1: 2.7843, One Epoch Time: 4.99m, Appro Left Time: 0.17h
#
# Train--Epoch: 8, Step: 4232/4233
# Eval--Epoch: 8, Step: 1058/1059	DDI Rate: 0.0607, Jaccard: 0.3658,  PRAUC: 0.5244, AVG_PRC: 0.4959, AVG_RECALL: 0.5696, AVG_F1: 0.5118
# avg med 15.41597191750768
# (0.06068916453430332, 0.36578596846440514, 0.524428965533588, 0.4958689268408543, 0.5696018869783783, 0.5118386026399993)
# 	Epoch: 8, Loss1: 2.7808, One Epoch Time: 5.01m, Appro Left Time: 0.08h
#
# Train--Epoch: 9, Step: 4232/4233
# Eval--Epoch: 9, Step: 1058/1059	DDI Rate: 0.0603, Jaccard: 0.3681,  PRAUC: 0.5180, AVG_PRC: 0.4992, AVG_RECALL: 0.5657, AVG_F1: 0.5098
# avg med 14.926283457656867
# (0.06027986653256063, 0.3680582568717829, 0.5180478755708771, 0.4991788589490635, 0.5657191677835025, 0.5097670255006336)
# 	Epoch: 9, Loss1: 2.7781, One Epoch Time: 5.02m, Appro Left Time: 0.00h

# %% [markdown]
# # Stop processing since we dont want to regenerate data pkl file for every notebook run

# %%
raise Exception
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-5-2aee0157c87b>", line 1, in <cell line: 1>
#     raise Exception
# Exception
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'Exception' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-5-2aee0157c87b>", line 1, in <cell line: 1>
#     raise Exception
# Exception
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'Exception' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-5-2aee0157c87b>", line 1, in <cell line: 1>
#     raise Exception
# Exception
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'Exception' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3492, in run_ast_nodes
#     self.showtraceback()
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1142, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected

# %% [markdown]
# # Data Processing - You can run this only if you want to regenerate the data files but this is not necessary

# %% [markdown]
# ## Read from MIMIC csv files

# %%
import pandas as pd
import os
# files can be downloaded from https://mimic.physionet.org/gettingstarted/dbsetup/
if is_colab:
    local_path = f"{path_to_root_folder}/data/"
    os.chdir(local_path)
else:
    local_path = ''

med_file = 'PRESCRIPTIONS.csv'
diag_file =  'DIAGNOSES_ICD.csv'
procedure_file =  'PROCEDURES_ICD.csv'

# drug code mapping files (already in ./data/)
ndc2atc_file = 'ndc2atc_level4.csv'
cid_atc = 'drug-atc.csv'
ndc_rxnorm_file = 'ndc2rxnorm_mapping.txt'

# drug-drug interactions can be down https://www.dropbox.com/s/8os4pd2zmp2jemd/drug-DDI.csv?dl=0
ddi_file = 'drug-DDI.csv'

def process_procedure():
    pro_pd = pd.read_csv(procedure_file, dtype={'ICD9_CODE':'category'})
    pro_pd.drop(columns=['ROW_ID'], inplace=True)
#     pro_pd = pro_pd[pro_pd['SEQ_NUM']<5]
#     def icd9_tree(x):
#         if x[0]=='E':
#             return x[:4]
#         return x[:3]
#     pro_pd['ICD9_CODE'] = pro_pd['ICD9_CODE'].map(icd9_tree)
    pro_pd.drop_duplicates(inplace=True)
    pro_pd.sort_values(by=['SUBJECT_ID', 'HADM_ID', 'SEQ_NUM'], inplace=True)
    pro_pd.drop(columns=['SEQ_NUM'], inplace=True)
    pro_pd.drop_duplicates(inplace=True)
    pro_pd.reset_index(drop=True, inplace=True)

    return pro_pd


def process_med():
    med_pd = pd.read_csv(med_file, dtype={'NDC':'category'})
    # filter
    med_pd.drop(columns=['ROW_ID','DRUG_TYPE','DRUG_NAME_POE','DRUG_NAME_GENERIC',
                     'FORMULARY_DRUG_CD','GSN','PROD_STRENGTH','DOSE_VAL_RX',
                     'DOSE_UNIT_RX','FORM_VAL_DISP','FORM_UNIT_DISP','FORM_UNIT_DISP',
                      'ROUTE','ENDDATE','DRUG'], axis=1, inplace=True)
    med_pd.drop(index = med_pd[med_pd['NDC'] == '0'].index, axis=0, inplace=True)
    med_pd.fillna(method='pad', inplace=True)
    med_pd.dropna(inplace=True)
    med_pd.drop_duplicates(inplace=True)
    med_pd['ICUSTAY_ID'] = med_pd['ICUSTAY_ID'].astype('int64')
    med_pd['STARTDATE'] = pd.to_datetime(med_pd['STARTDATE'], format='%Y-%m-%d %H:%M:%S')
    med_pd.sort_values(by=['SUBJECT_ID', 'HADM_ID', 'ICUSTAY_ID', 'STARTDATE'], inplace=True)
    med_pd = med_pd.reset_index(drop=True)

    def filter_first24hour_med(med_pd):
        med_pd_new = med_pd.drop(columns=['NDC'])
        med_pd_new = med_pd_new.groupby(by=['SUBJECT_ID','HADM_ID','ICUSTAY_ID']).head(1).reset_index(drop=True)
        med_pd_new = pd.merge(med_pd_new, med_pd, on=['SUBJECT_ID','HADM_ID','ICUSTAY_ID','STARTDATE'])
        med_pd_new = med_pd_new.drop(columns=['STARTDATE'])
        return med_pd_new
    med_pd = filter_first24hour_med(med_pd)
#     med_pd = med_pd.drop(columns=['STARTDATE'])

    med_pd = med_pd.drop(columns=['ICUSTAY_ID'])
    med_pd = med_pd.drop_duplicates()
    med_pd = med_pd.reset_index(drop=True)

    # visit > 2
    def process_visit_lg2(med_pd):
        a = med_pd[['SUBJECT_ID', 'HADM_ID']].groupby(by='SUBJECT_ID')['HADM_ID'].unique().reset_index()
        a['HADM_ID_Len'] = a['HADM_ID'].map(lambda x:len(x))
        a = a[a['HADM_ID_Len'] > 1]
        return a
    med_pd_lg2 = process_visit_lg2(med_pd).reset_index(drop=True)
    med_pd = med_pd.merge(med_pd_lg2[['SUBJECT_ID']], on='SUBJECT_ID', how='inner')

    return med_pd.reset_index(drop=True)

def process_diag():
    diag_pd = pd.read_csv(diag_file)
    diag_pd.dropna(inplace=True)
#     def icd9_tree(x):
#         if x[0]=='E':
#             return x[:4]
#         return x[:3]
#     diag_pd['ICD9_CODE'] = diag_pd['ICD9_CODE'].map(icd9_tree)
#     diag_pd = diag_pd[diag_pd['SEQ_NUM'] < 5]
    diag_pd.drop(columns=['SEQ_NUM','ROW_ID'],inplace=True)
    diag_pd.drop_duplicates(inplace=True)
    diag_pd.sort_values(by=['SUBJECT_ID','HADM_ID'], inplace=True)
    return diag_pd.reset_index(drop=True)

def ndc2atc4(med_pd):
    with open(ndc_rxnorm_file, 'r') as f:
        ndc2rxnorm = eval(f.read())
    med_pd['RXCUI'] = med_pd['NDC'].map(ndc2rxnorm)
    med_pd.dropna(inplace=True)

    rxnorm2atc = pd.read_csv(ndc2atc_file)
    rxnorm2atc = rxnorm2atc.drop(columns=['YEAR','MONTH','NDC'])
    rxnorm2atc.drop_duplicates(subset=['RXCUI'], inplace=True)
    med_pd.drop(index = med_pd[med_pd['RXCUI'].isin([''])].index, axis=0, inplace=True)

    med_pd['RXCUI'] = med_pd['RXCUI'].astype('int64')
    med_pd = med_pd.reset_index(drop=True)
    med_pd = med_pd.merge(rxnorm2atc, on=['RXCUI'])
    med_pd.drop(columns=['NDC', 'RXCUI'], inplace=True)
    med_pd = med_pd.rename(columns={'ATC4':'NDC'})
    med_pd['NDC'] = med_pd['NDC'].map(lambda x: x[:4])
    med_pd = med_pd.drop_duplicates()
    med_pd = med_pd.reset_index(drop=True)
    return med_pd

def filter_1000_most_pro(pro_pd):
    pro_count = pro_pd.groupby(by=['ICD9_CODE']).size().reset_index().rename(columns={0:'count'}).sort_values(by=['count'],ascending=False).reset_index(drop=True)
    pro_pd = pro_pd[pro_pd['ICD9_CODE'].isin(pro_count.loc[:1000, 'ICD9_CODE'])]

    return pro_pd.reset_index(drop=True)

def filter_2000_most_diag(diag_pd):
    diag_count = diag_pd.groupby(by=['ICD9_CODE']).size().reset_index().rename(columns={0:'count'}).sort_values(by=['count'],ascending=False).reset_index(drop=True)
    diag_pd = diag_pd[diag_pd['ICD9_CODE'].isin(diag_count.loc[:1999, 'ICD9_CODE'])]

    return diag_pd.reset_index(drop=True)

def filter_300_most_med(med_pd):
    med_count = med_pd.groupby(by=['NDC']).size().reset_index().rename(columns={0:'count'}).sort_values(by=['count'],ascending=False).reset_index(drop=True)
    med_pd = med_pd[med_pd['NDC'].isin(med_count.loc[:299, 'NDC'])]

    return med_pd.reset_index(drop=True)

def process_all():
    # get med and diag (visit>=2)
    med_pd = process_med()
    med_pd = ndc2atc4(med_pd)
#     med_pd = filter_300_most_med(med_pd)

    diag_pd = process_diag()
    diag_pd = filter_2000_most_diag(diag_pd)

    pro_pd = process_procedure()
#     pro_pd = filter_1000_most_pro(pro_pd)

    med_pd_key = med_pd[['SUBJECT_ID', 'HADM_ID']].drop_duplicates()
    diag_pd_key = diag_pd[['SUBJECT_ID', 'HADM_ID']].drop_duplicates()
    pro_pd_key = pro_pd[['SUBJECT_ID', 'HADM_ID']].drop_duplicates()

    combined_key = med_pd_key.merge(diag_pd_key, on=['SUBJECT_ID', 'HADM_ID'], how='inner')
    combined_key = combined_key.merge(pro_pd_key, on=['SUBJECT_ID', 'HADM_ID'], how='inner')

    diag_pd = diag_pd.merge(combined_key, on=['SUBJECT_ID', 'HADM_ID'], how='inner')
    med_pd = med_pd.merge(combined_key, on=['SUBJECT_ID', 'HADM_ID'], how='inner')
    pro_pd = pro_pd.merge(combined_key, on=['SUBJECT_ID', 'HADM_ID'], how='inner')

    # flatten and merge
    diag_pd = diag_pd.groupby(by=['SUBJECT_ID','HADM_ID'])['ICD9_CODE'].unique().reset_index()
    med_pd = med_pd.groupby(by=['SUBJECT_ID', 'HADM_ID'])['NDC'].unique().reset_index()
    pro_pd = pro_pd.groupby(by=['SUBJECT_ID','HADM_ID'])['ICD9_CODE'].unique().reset_index().rename(columns={'ICD9_CODE':'PRO_CODE'})
    med_pd['NDC'] = med_pd['NDC'].map(lambda x: list(x))
    pro_pd['PRO_CODE'] = pro_pd['PRO_CODE'].map(lambda x: list(x))
    data = diag_pd.merge(med_pd, on=['SUBJECT_ID', 'HADM_ID'], how='inner')
    data = data.merge(pro_pd, on=['SUBJECT_ID', 'HADM_ID'], how='inner')
#     data['ICD9_CODE_Len'] = data['ICD9_CODE'].map(lambda x: len(x))
    data['NDC_Len'] = data['NDC'].map(lambda x: len(x))
    return data

def statistics():
    print('#patients ', data['SUBJECT_ID'].unique().shape)
    print('#clinical events ', len(data))

    diag = data['ICD9_CODE'].values
    med = data['NDC'].values
    pro = data['PRO_CODE'].values

    unique_diag = set([j for i in diag for j in list(i)])
    unique_med = set([j for i in med for j in list(i)])
    unique_pro = set([j for i in pro for j in list(i)])

    print('#diagnosis ', len(unique_diag))
    print('#med ', len(unique_med))
    print('#procedure', len(unique_pro))

    avg_diag = 0
    avg_med = 0
    avg_pro = 0
    max_diag = 0
    max_med = 0
    max_pro = 0
    cnt = 0
    max_visit = 0
    avg_visit = 0

    for subject_id in data['SUBJECT_ID'].unique():
        item_data = data[data['SUBJECT_ID'] == subject_id]
        x = []
        y = []
        z = []
        visit_cnt = 0
        for index, row in item_data.iterrows():
            visit_cnt += 1
            cnt += 1
            x.extend(list(row['ICD9_CODE']))
            y.extend(list(row['NDC']))
            z.extend(list(row['PRO_CODE']))
        x = set(x)
        y = set(y)
        z = set(z)
        avg_diag += len(x)
        avg_med += len(y)
        avg_pro += len(z)
        avg_visit += visit_cnt
        if len(x) > max_diag:
            max_diag = len(x)
        if len(y) > max_med:
            max_med = len(y)
        if len(z) > max_pro:
            max_pro = len(z)
        if visit_cnt > max_visit:
            max_visit = visit_cnt



    print('#avg of diagnoses ', avg_diag/ cnt)
    print('#avg of medicines ', avg_med/ cnt)
    print('#avg of procedures ', avg_pro/ cnt)
    print('#avg of vists ', avg_visit/ len(data['SUBJECT_ID'].unique()))


    print('#max of diagnoses ', max_diag)
    print('#max of medicines ', max_med)
    print('#max of procedures ', max_pro)
    print('#max of visit ', max_visit)



data = process_all()
statistics()
data.to_pickle('data_final.pkl')
data.head()
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-5-7e8d969e4f1b>", line 1, in <cell line: 1>
#     import pandas as pd
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1002, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 945, in _find_spec
#   File "<frozen importlib._bootstrap_external>", line 1439, in find_spec
#   File "<frozen importlib._bootstrap_external>", line 1408, in _get_spec
#   File "<frozen importlib._bootstrap_external>", line 1366, in _path_importer_cache
# OSError: [Errno 107] Transport endpoint is not connected
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'OSError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-5-7e8d969e4f1b>", line 1, in <cell line: 1>
#     import pandas as pd
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1002, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 945, in _find_spec
#   File "<frozen importlib._bootstrap_external>", line 1439, in find_spec
#   File "<frozen importlib._bootstrap_external>", line 1408, in _get_spec
#   File "<frozen importlib._bootstrap_external>", line 1366, in _path_importer_cache
# OSError: [Errno 107] Transport endpoint is not connected
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'OSError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-5-7e8d969e4f1b>", line 1, in <cell line: 1>
#     import pandas as pd
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1002, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 945, in _find_spec
#   File "<frozen importlib._bootstrap_external>", line 1439, in find_spec
#   File "<frozen importlib._bootstrap_external>", line 1408, in _get_spec
#   File "<frozen importlib._bootstrap_external>", line 1366, in _path_importer_cache
# OSError: [Errno 107] Transport endpoint is not connected
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'OSError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3492, in run_ast_nodes
#     self.showtraceback()
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1142, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected

# %% [markdown]
# ## Create Vocaboray for Medical Codes & Save Patient Record in pickle form

# %%
import dill
import pandas as pd
class Voc(object):
    def __init__(self):
        self.idx2word = {}
        self.word2idx = {}

    def add_sentence(self, sentence):
        for word in sentence:
            if word not in self.word2idx:
                self.idx2word[len(self.word2idx)] = word
                self.word2idx[word] = len(self.word2idx)

def create_str_token_mapping(df):
    diag_voc = Voc()
    med_voc = Voc()
    pro_voc = Voc()
    ## only for DMNC
#     diag_voc.add_sentence(['seperator', 'decoder_point'])
#     med_voc.add_sentence(['seperator', 'decoder_point'])
#     pro_voc.add_sentence(['seperator', 'decoder_point'])

    for index, row in df.iterrows():
        diag_voc.add_sentence(row['ICD9_CODE'])
        med_voc.add_sentence(row['NDC'])
        pro_voc.add_sentence(row['PRO_CODE'])

    dill.dump(obj={'diag_voc':diag_voc, 'med_voc':med_voc ,'pro_voc':pro_voc}, file=open('voc_final.pkl','wb'))
    return diag_voc, med_voc, pro_voc

def create_patient_record(df, diag_voc, med_voc, pro_voc):
    records = [] # (patient, code_kind:3, codes)  code_kind:diag, proc, med
    for subject_id in df['SUBJECT_ID'].unique():
        item_df = df[df['SUBJECT_ID'] == subject_id]
        patient = []
        for index, row in item_df.iterrows():
            admission = []
            admission.append([diag_voc.word2idx[i] for i in row['ICD9_CODE']])
            admission.append([pro_voc.word2idx[i] for i in row['PRO_CODE']])
            admission.append([med_voc.word2idx[i] for i in row['NDC']])
            patient.append(admission)
        records.append(patient)
    dill.dump(obj=records, file=open('records_final.pkl', 'wb'))
    return records


path='data_final.pkl'
df = pd.read_pickle(path)
diag_voc, med_voc, pro_voc = create_str_token_mapping(df)
records = create_patient_record(df, diag_voc, med_voc, pro_voc)
len(diag_voc.idx2word), len(med_voc.idx2word), len(pro_voc.idx2word)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-5-54ab45a14479>", line 1, in <cell line: 1>
#     import dill
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1002, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 945, in _find_spec
#   File "<frozen importlib._bootstrap_external>", line 1439, in find_spec
#   File "<frozen importlib._bootstrap_external>", line 1408, in _get_spec
#   File "<frozen importlib._bootstrap_external>", line 1366, in _path_importer_cache
# OSError: [Errno 107] Transport endpoint is not connected
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'OSError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-5-54ab45a14479>", line 1, in <cell line: 1>
#     import dill
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1002, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 945, in _find_spec
#   File "<frozen importlib._bootstrap_external>", line 1439, in find_spec
#   File "<frozen importlib._bootstrap_external>", line 1408, in _get_spec
#   File "<frozen importlib._bootstrap_external>", line 1366, in _path_importer_cache
# OSError: [Errno 107] Transport endpoint is not connected
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'OSError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-5-54ab45a14479>", line 1, in <cell line: 1>
#     import dill
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1002, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 945, in _find_spec
#   File "<frozen importlib._bootstrap_external>", line 1439, in find_spec
#   File "<frozen importlib._bootstrap_external>", line 1408, in _get_spec
#   File "<frozen importlib._bootstrap_external>", line 1366, in _path_importer_cache
# OSError: [Errno 107] Transport endpoint is not connected
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'OSError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3492, in run_ast_nodes
#     self.showtraceback()
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1142, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected

# %% [markdown]
# ## DDI & Construct EHR Adj and DDI Adj

# %%
import pandas as pd
import numpy as np
from collections import defaultdict
import dill

# atc -> cid
ddi_file = 'drug-DDI.csv'
cid_atc = 'drug-atc.csv'
voc_file = 'voc_final.pkl'
data_path = 'records_final.pkl'
TOPK = 40 # topk drug-drug interaction

records =  dill.load(open(data_path, 'rb'))
cid2atc_dic = defaultdict(set)
med_voc = dill.load(open(voc_file, 'rb'))['med_voc']
med_voc_size = len(med_voc.idx2word)
med_unique_word = [med_voc.idx2word[i] for i in range(med_voc_size)]
atc3_atc4_dic = defaultdict(set)
for item in med_unique_word:
    atc3_atc4_dic[item[:4]].add(item)


with open(cid_atc, 'r') as f:
    for line in f:
        line_ls = line[:-1].split(',')
        cid = line_ls[0]
        atcs = line_ls[1:]
        for atc in atcs:
            if len(atc3_atc4_dic[atc[:4]]) != 0:
                cid2atc_dic[cid].add(atc[:4])

# ddi load
ddi_df = pd.read_csv(ddi_file)
# fliter sever side effect
ddi_most_pd = ddi_df.groupby(by=['Polypharmacy Side Effect', 'Side Effect Name']).size().reset_index().rename(columns={0:'count'}).sort_values(by=['count'],ascending=False).reset_index(drop=True)
ddi_most_pd = ddi_most_pd.iloc[-TOPK:,:]
# ddi_most_pd = pd.DataFrame(columns=['Side Effect Name'], data=['as','asd','as'])
fliter_ddi_df = ddi_df.merge(ddi_most_pd[['Side Effect Name']], how='inner', on=['Side Effect Name'])
ddi_df = fliter_ddi_df[['STITCH 1','STITCH 2']].drop_duplicates().reset_index(drop=True)

# weighted ehr adj
ehr_adj = np.zeros((med_voc_size, med_voc_size))
for patient in records:
    for adm in patient:
        med_set = adm[2]
        for i, med_i in enumerate(med_set):
            for j, med_j in enumerate(med_set):
                if j<=i:
                    continue
                ehr_adj[med_i, med_j] = 1
                ehr_adj[med_j, med_i] = 1
dill.dump(ehr_adj, open('ehr_adj_final.pkl', 'wb'))



# ddi adj
ddi_adj = np.zeros((med_voc_size,med_voc_size))
for index, row in ddi_df.iterrows():
    # ddi
    cid1 = row['STITCH 1']
    cid2 = row['STITCH 2']

    # cid -> atc_level3
    for atc_i in cid2atc_dic[cid1]:
        for atc_j in cid2atc_dic[cid2]:

            # atc_level3 -> atc_level4
            for i in atc3_atc4_dic[atc_i]:
                for j in atc3_atc4_dic[atc_j]:
                    if med_voc.word2idx[i] != med_voc.word2idx[j]:
                        ddi_adj[med_voc.word2idx[i], med_voc.word2idx[j]] = 1
                        ddi_adj[med_voc.word2idx[j], med_voc.word2idx[i]] = 1
dill.dump(ddi_adj, open('ddi_A_final.pkl', 'wb'))

print('complete!')
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-5-8c691d64d0e7>", line 1, in <cell line: 1>
#     import pandas as pd
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1002, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 945, in _find_spec
#   File "<frozen importlib._bootstrap_external>", line 1439, in find_spec
#   File "<frozen importlib._bootstrap_external>", line 1408, in _get_spec
#   File "<frozen importlib._bootstrap_external>", line 1366, in _path_importer_cache
# OSError: [Errno 107] Transport endpoint is not connected
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'OSError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-5-8c691d64d0e7>", line 1, in <cell line: 1>
#     import pandas as pd
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1002, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 945, in _find_spec
#   File "<frozen importlib._bootstrap_external>", line 1439, in find_spec
#   File "<frozen importlib._bootstrap_external>", line 1408, in _get_spec
#   File "<frozen importlib._bootstrap_external>", line 1366, in _path_importer_cache
# OSError: [Errno 107] Transport endpoint is not connected
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'OSError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-5-8c691d64d0e7>", line 1, in <cell line: 1>
#     import pandas as pd
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1002, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 945, in _find_spec
#   File "<frozen importlib._bootstrap_external>", line 1439, in find_spec
#   File "<frozen importlib._bootstrap_external>", line 1408, in _get_spec
#   File "<frozen importlib._bootstrap_external>", line 1366, in _path_importer_cache
# OSError: [Errno 107] Transport endpoint is not connected
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'OSError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3492, in run_ast_nodes
#     self.showtraceback()
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1142, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected

# %% [markdown]
# #References
# [1] Johnson, A., Pollard, T., & Mark, R. (2016, September 4). Mimic-III clinical database. MIMIC-III Clinical Database v1.4. https://physionet.org/content/mimiciii/1.4/
#
# [2] Offsides and twosides (NSIDES v0.1) – tlab. (n.d.). http://tatonettilab.org/offsides/
#
# [3] Shang, J., Xiao, C., Ma, T., Li, H., & Sun, J. (2019). GAMENet: Graph Augmented MEmory networks for recommending medication combination. Proceedings of the . . . AAAI Conference on Artificial Intelligence, 33(01), 1126–1133. https://doi.org/10.1609/aaai.v33i01.33011126
